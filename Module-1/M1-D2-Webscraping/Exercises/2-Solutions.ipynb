# %% [markdown]
# ### Working with APIs##
# #Exercises#

# %% [markdown]
# ---
#
#
# <font color='violet'>
# Hints are written in white, so you do not see them immediately. If you highlight them (or double-click on them), they will appear!
# <font color='white'> I am a hint! :-)
#
#
# ---

# %% [markdown]
# ## 1. Basic exercises

# %% [markdown]
# Note: In these exercises, you will have to work with dictionaries, list comprehensions and loops quite often. If you don't remember/understand them very well, you should first go through the respective concepts once more!

# %% [markdown]
# ### Exercise 1.1

# %% [markdown]
# Import the ``requests`` and the ``BeautifulSoup`` library.

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# Use the Wikipedia API to retrieve the Wikipedia page on tigers (Tiger).

# %%
URL = "https://en.wikipedia.org/w/api.php"

PARAMS = {
    "action": "parse",
    "page": "Tiger",
    "format": "json",
}

r = requests.get(url=URL, params=PARAMS)

# %% [markdown]
# Parse the JSON response object (so that it is converted to a Python dictionary).

# %%
tiger = r.json()

# %% [markdown]
# What is the URL you retrieved the data from? Type it into your browser and inspect the structure of the data.

# %%
r.url
# Out:
# 'https://en.wikipedia.org/w/api.php?action=parse&page=Tiger&format=json'

# %% [markdown]
# Now inspect the keys of your dictionary (and those of the dictionary within the "parse" key)

# %%
tiger.keys()
# Out:
# dict_keys(['parse'])

# %%
tiger["parse"].keys()
# Note: To save some coding below, you could type: tiger = tiger["parse"]
# Out:
# dict_keys(['title', 'pageid', 'revid', 'text', 'langlinks', 'categories', 'links', 'templates', 'images', 'externallinks', 'sections', 'showtoc', 'parsewarnings', 'displaytitle', 'iwlinks', 'properties'])

# %% [markdown]
# Now try to retrieve the following:
#
# 1. The title of the page
# 2. All external links
# 3. All section headings (*extra task: all main section headings, i.e. headings on level 2)
# 4. The number of images in the article
# 5. All URLs to Wikipedia articles on tigers in other languages

# %%
# 1. The title of the page
tiger["parse"]["title"]
# Out:
# 'Tiger'

# %%
# 2. All external links
print(tiger["parse"]["externallinks"])
# Out:
# ['https://www.iucnredlist.org/species/15955/214862019', 'https://doi.org/10.2305%2FIUCN.UK.2022-1.RLTS.T15955A214862019.en', 'https://archive.org/stream/mobot31753000798865#page/41/mode/2up', 'https://archive.org/details/checklistofpalae00elle/page/318/mode/2up', 'https://www.perseus.tufts.edu/hopper/text?doc=Perseus:text:1999.04.0057:entry%3Dti/gris', 'https://web.archive.org/web/20201021200154/http://www.perseus.tufts.edu/hopper/text?doc=Perseus:text:1999.04.0057:entry=ti/gris', 'https://archive.org/details/onlatinlanguage01varruoft/page/96/mode/2up', 'https://doi.org/10.1086%2F693884', 'https://www.jstor.org/stable/26560471', 'https://api.semanticscholar.org/CorpusID:165388712', 'https://archive.org/details/journalofbomb33341929bomb/page/n133', 'https://archive.org/stream/PocockMammalia1/pocock1#page/n247/mode/2up', 'http://www.departments.bucknell.edu/biology/resources/msw3/browse.asp?id=14000259', 'http://www.google.com/books?id=JgAMbNSt8ikC&pg=PA546', 'https://search.worldcat.org/oclc/62265494', 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4640610', 'https://ui.adsabs.harvard.edu/abs/2015SciA....1E0175W', 'https://doi.org/10.1126%2Fsciadv.1400175', 'https://pubmed.ncbi.nlm.nih.gov/26601191', 'https://repository.si.edu/bitstream/handle/10088/32616/A_revised_Felidae_Taxonomy_CatNews.pdf?sequence=1&isAllowed=y#page=66', 'https://web.archive.org/web/20200117172708/https://repository.si.edu/bitstream/handle/10088/32616/A_revised_Felidae_Taxonomy_CatNews.pdf?sequence=1&isAllowed=y#page=66', 'https://doi.org/10.1016%2Fj.cub.2018.09.019', 'https://ui.adsabs.harvard.edu/abs/2018CBio...28E3840L', 'https://pubmed.ncbi.nlm.nih.gov/30482605', 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8136513', 'https://doi.org/10.1093%2Fmolbev%2Fmsab032', 'https://pubmed.ncbi.nlm.nih.gov/33592092', 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC10111772', 'https://doi.org/10.1186%2Fs12915-023-01552-y', 'https://pubmed.ncbi.nlm.nih.gov/37069598', 'http://www.catsg.org/index.php?id=124', 'https://portals.iucn.org/library/sites/library/files/documents/1996-008.pdf#page=80', 'https://web.archive.org/web/20240125121859/https://portals.iucn.org/library/sites/library/files/documents/1996-008.pdf#page=80', 'https://cza.nic.in/uploads/documents/studbooks/english/Bengal%20Tiger%20Studbook%202011.pdf', 'https://ui.adsabs.harvard.edu/abs/2010MamBi..75...45M', 'https://doi.org/10.1016%2Fj.mambio.2008.06.003', 'https://bibliothek.bbaw.de/digitalisierte-sammlungen/akademieschriften/ansicht-akademieschriften?tx_bbaw_academicpublicationshow%5Baction%5D=show&tx_bbaw_academicpublicationshow%5Bcontroller%5D=AcademicPublication%5CVolume&tx_bbaw_academicpublicationshow%5Bpage%5D=195&tx_bbaw_academicpublicationshow%5Bvolume%5D=85&cHash=f015ec3f9a13240a9559ebdcb88aafa4', 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2624500', 'https://ui.adsabs.harvard.edu/abs/2009PLoSO...4.4125D', 'https://doi.org/10.1371%2Fjournal.pone.0004125', 'https://pubmed.ncbi.nlm.nih.gov/19142238', 'https://archive.org/details/faunajaponicasi00sieb/page/43', 'https://archive.org/details/zoologischeranze28deut/page/596', 'https://ui.adsabs.harvard.edu/abs/2023NatEE...7.1914S', 'https://doi.org/10.1038%2Fs41559-023-02185-8', 'https://pubmed.ncbi.nlm.nih.gov/37652999', 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC9326283', 'https://doi.org/10.1098%2Frspb.2022.0617', 'https://pubmed.ncbi.nlm.nih.gov/35892215', 'https://doi.org/10.1515%2Fmamm.1968.32.1.104', 'https://api.semanticscholar.org/CorpusID:84054536', 'http://www.dl.edi-info.ir/A%20taxonomic%20revision%20of%20the%20tigers%20of%20Southeast%20Asia.pdf', 'https://ui.adsabs.harvard.edu/abs/2006MamBi..71..268M', 'https://doi.org/10.1016%2Fj.mambio.2006.02.007', 'https://web.archive.org/web/20230531133543/http://www.dl.edi-info.ir/A%20taxonomic%20revision%20of%20the%20tigers%20of%20Southeast%20Asia.pdf', 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC534810', 'https://doi.org/10.1371%2Fjournal.pbio.0020442', 'https://pubmed.ncbi.nlm.nih.gov/15583 ...

# %%
# 3. All section headings
sections = tiger["parse"]["sections"]
[section["line"] for section in sections]
# Out:
# ['Etymology',
#  'Taxonomy',
#  'Subspecies',
#  'Evolution',
#  'Hybrids',
#  'Characteristics',
#  'Coat',
#  'Colour variations',
#  'Distribution and habitat',
#  'Population density',
#  'Behaviour and ecology',
#  'Social spacing',
#  'Communication',
#  'Hunting and diet',
#  'Competitors',
#  'Reproduction and life cycle',
#  'Health and diseases',
#  'Threats',
#  'Conservation',
#  'Relationship with humans',
#  'Hunting',
#  'Attacks',
#  'Captivity',
#  'Cultural significance',
#  'See also',
#  'References',
#  'Bibliography',
#  'External links']

# %%
# 3. Extra task: all top level section headings (level 2)
[section["line"] for section in sections if section["level"]=="2"]
# Out:
# ['Etymology',
#  'Taxonomy',
#  'Characteristics',
#  'Distribution and habitat',
#  'Behaviour and ecology',
#  'Threats',
#  'Conservation',
#  'Relationship with humans',
#  'See also',
#  'References',
#  'External links']

# %%
# 4. The number of images in the article
len(tiger["parse"]["images"])
# Out:
# 63

# %%
# 5. All URLs to Wikipedia articles on tigers in other languages
languages = tiger["parse"]["langlinks"]

langlinks = [elem["url"] for elem in languages]
print(langlinks)
# Out:
# ['https://ace.wikipedia.org/wiki/Rimu%C3%ABng', 'https://kbd.wikipedia.org/wiki/%D0%A5%D1%8C%D1%8D%D1%89%D0%BE%D0%BC%D1%8B%D1%89', 'https://ady.wikipedia.org/wiki/%D0%9A%D1%8A%D1%8D%D0%BF%D0%BB%D1%8A%D0%B0%D0%BD', 'https://af.wikipedia.org/wiki/Tier', 'https://als.wikipedia.org/wiki/Tiger', 'https://am.wikipedia.org/wiki/%E1%8A%90%E1%89%A5%E1%88%AD', 'https://anp.wikipedia.org/wiki/%E0%A4%AC%E0%A4%BE%E0%A4%98', 'https://ang.wikipedia.org/wiki/Tiger', 'https://ar.wikipedia.org/wiki/%D8%A8%D8%A8%D8%B1', 'https://an.wikipedia.org/wiki/Panthera_tigris', 'https://roa-rup.wikipedia.org/wiki/Tigru', 'https://ast.wikipedia.org/wiki/Panthera_tigris', 'https://gn.wikipedia.org/wiki/Jaguareterusu', 'https://az.wikipedia.org/wiki/P%C9%99l%C9%99ng', 'https://azb.wikipedia.org/wiki/%D9%82%D8%A7%D9%BE%D9%84%D8%A7%D9%86', 'https://ban.wikipedia.org/wiki/Macan', 'https://bn.wikipedia.org/wiki/%E0%A6%AC%E0%A6%BE%E0%A6%98', 'https://zh-min-nan.wikipedia.org/wiki/H%C3%B3%CD%98', 'https://ba.wikipedia.org/wiki/%D0%AE%D0%BB%D0%B1%D0%B0%D1%80%D1%8B%D2%AB', 'https://be.wikipedia.org/wiki/%D0%A2%D1%8B%D0%B3%D1%80', 'https://be-tarask.wikipedia.org/wiki/%D0%A2%D1%8B%D0%B3%D1%80', 'https://bh.wikipedia.org/wiki/%E0%A4%AC%E0%A4%BE%E0%A4%98', 'https://bcl.wikipedia.org/wiki/Tigre', 'https://bg.wikipedia.org/wiki/%D0%A2%D0%B8%D0%B3%D1%8A%D1%80', 'https://bo.wikipedia.org/wiki/%E0%BD%A6%E0%BE%9F%E0%BD%82', 'https://bs.wikipedia.org/wiki/Tigar', 'https://br.wikipedia.org/wiki/Tigr', 'https://bxr.wikipedia.org/wiki/%D0%91%D0%B0%D1%80', 'https://ca.wikipedia.org/wiki/Tigre', 'https://cv.wikipedia.org/wiki/%D0%A2%D0%B8%D0%B3%D1%80', 'https://ceb.wikipedia.org/wiki/Panthera_tigris', 'https://cs.wikipedia.org/wiki/Tygr', 'https://co.wikipedia.org/wiki/Tigru', 'https://cy.wikipedia.org/wiki/Teigr', 'https://da.wikipedia.org/wiki/Tiger', 'https://de.wikipedia.org/wiki/Tiger', 'https://nv.wikipedia.org/wiki/N%C3%A1shd%C3%B3%C3%ADtsoh_nood%C7%AB%CC%81z%C3%ADg%C3%AD%C3%AD', 'https://dty.wikipedia.org/wiki/%E0%A4%AC%E0%A4%BE%E0%A4%97', 'https://dz.wikipedia.org/wiki/%E0%BD%A6%E0%BE%9F%E0%BD%82', 'https://et.wikipedia.org/wiki/Tiiger', 'https://el.wikipedia.org/wiki/%CE%A4%CE%AF%CE%B3%CF%81%CE%B7', 'https://es.wikipedia.org/wiki/Panthera_tigris', 'https://eo.wikipedia.org/wiki/Tigro', 'https://eu.wikipedia.org/wiki/Tigre', 'https://fa.wikipedia.org/wiki/%D8%A8%D8%A8%D8%B1', 'https://fo.wikipedia.org/wiki/Tikari', 'https://fr.wikipedia.org/wiki/Tigre', 'https://ga.wikipedia.org/wiki/T%C3%ADogar', 'https://gag.wikipedia.org/wiki/Kaplan', 'https://gd.wikipedia.org/wiki/T%C3%ACgear', 'https://gl.wikipedia.org/wiki/Tigre', 'https://inh.wikipedia.org/wiki/%D0%A6%D3%80%D0%BE%D0%BA%D1%8A', 'https://gan.wikipedia.org/wiki/%E8%80%81%E8%99%8E', 'https://glk.wikipedia.org/wiki/%D8%AF%DB%8A%D8%B1%DA%AF', 'https://gu.wikipedia.org/wiki/%E0%AA%B5%E0%AA%BE%E0%AA%98', 'https://got.wikipedia.org/wiki/%F0%90%8D%84%F0%90%8C%B9%F0%90%8C%B2%F0%90%8D%82%F0%90%8D%83', 'https://gom.wikipedia.org/wiki/Vag', 'https://hak.wikipedia.org/wiki/Lo-f%C3%BA', 'https://ko.wikipedia.org/wiki/%ED%98%B8%EB%9E%91%EC%9D%B4', 'https://hy.wikipedia.org/wiki/%D5%8E%D5%A1%D5%A3%D6%80', 'https://hi.wikipedia.org/wiki/%E0%A4%AC%E0%A4%BE%E0%A4%98', 'https://hsb.wikipedia.org/wiki/Tiger', 'https://hr.wikipedia.org/wiki/Tigar', 'https://io.wikipedia.org/wiki/Tigro', 'https://ilo.wikipedia.org/wiki/Tigre', 'https://id.wikipedia.org/wiki/Harimau', 'https://ia.wikipedia.org/wiki/Tigre', 'https://os.wikipedia.org/wiki/%D0%A2%D0%B8%D0%B3%D1%80', 'https://zu.wikipedia.org/wiki/Ithayiga', 'https://is.wikipedia.org/wiki/T%C3%ADgrisd%C3%BDr', 'https://it.wikipedia.org/wiki/Panthera_tigris', 'https://he.wikipedia.org/wiki/%D7%98%D7%99%D7%92%D7%A8%D7%99%D7%A1', 'https://jv.wikipedia.org/wiki/Macan', 'https://kn.wikipedia.org/wiki/%E0%B2%B9%E0%B3%81%E0%B2%B2%E0%B2%BF', 'https://ka.wikipedia.org/wiki/%E1%83%95%E1%83%94%E1%83%A4%E1%83%AE%E1%83%95%E1%83%98', 'https://ks.wikipedia.org/wiki/%D8%B4%DB%8C%D8%B1', 'https://csb.wikipedia. ...

# %% [markdown]
# Repetition (dictionaries and loops): Now make a dictionary of all languages for which a Wikipedia page exists as well as the titles of these pages. Use the languages as keys and the titles as values (`{"English":"Tiger", ...}`). How are tigers called in `Finnish`?

# %%
tiger_lang = {"English":"Tiger"}
for elem in languages:
  tiger_lang[elem["langname"]] = elem["*"]
tiger_lang
# Out:
# {'English': 'Tiger',
#  'Achinese': 'Rimuëng',
#  'Kabardian': 'Хьэщомыщ',
#  'Adyghe': 'Къэплъан',
#  'Afrikaans': 'Tier',
#  'Alemannic': 'Tiger',
#  'Amharic': 'ነብር',
#  'Angika': 'बाघ',
#  'Old English': 'Tiger',
#  'Arabic': 'ببر',
#  'Aragonese': 'Panthera tigris',
#  'Aromanian': 'Tigru',
#  'Asturian': 'Panthera tigris',
#  'Guarani': 'Jaguareterusu',
#  'Azerbaijani': 'Pələng',
#  'South Azerbaijani': 'قاپلان',
#  'Balinese': 'Macan',
#  'Bangla': 'বাঘ',
#  'Minnan': 'Hó͘',
#  'Bashkir': 'Юлбарыҫ',
#  'Belarusian': 'Тыгр',
#  'Belarusian (Taraškievica orthography)': 'Тыгр',
#  'Bhojpuri': 'बाघ',
#  'Central Bikol': 'Tigre',
#  'Bulgarian': 'Тигър',
#  'Tibetan': 'སྟག',
#  'Bosnian': 'Tigar',
#  'Breton': 'Tigr',
#  'Russia Buriat': 'Бар',
#  'Catalan': 'Tigre',
#  'Chuvash': 'Тигр',
#  'Cebuano': 'Panthera tigris',
#  'Czech': 'Tygr',
#  'Corsican': 'Tigru',
#  'Welsh': 'Teigr',
#  'Danish': 'Tiger',
#  'German': 'Tiger',
#  'Navajo': 'Náshdóítsoh noodǫ́zígíí',
#  'Doteli': 'बाग',
#  'Dzongkha': 'སྟག',
#  'Estonian': 'Tiiger',
#  'Greek': 'Τίγρη',
#  'Spanish': 'Panthera tigris',
#  'Esperanto': 'Tigro',
#  'Basque': 'Tigre',
#  'Persian': 'ببر',
#  'Faroese': 'Tikari',
#  'French': 'Tigre',
#  'Irish': 'Tíogar',
#  'Gagauz': 'Kaplan',
#  'Scottish Gaelic': 'Tìgear',
#  'Galician': 'Tigre',
#  'Ingush': 'ЦӀокъ',
#  'Gan': '老虎',
#  'Gilaki': 'دۊرگ',
#  'Gujarati': 'વાઘ',
#  'Gothic': '𐍄𐌹𐌲𐍂𐍃',
#  'Goan Konkani': 'Vag',
#  'Hakka Chinese': 'Lo-fú',
#  'Korean': '호랑이',
#  'Armenian': 'Վագր',
#  'Hindi': 'बाघ',
#  'Upper Sorbian': 'Tiger',
#  'Croatian': 'Tigar',
#  'Ido': 'Tigro',
#  'Iloko': 'Tigre',
#  'Indonesian': 'Harimau',
#  'Interlingua': 'Tigre',
#  'Ossetic': 'Тигр',
#  'Zulu': 'Ithayiga',
#  'Icelandic': 'Tígrisdýr',
#  'Italian': 'Panthera tigris',
#  'Hebrew': 'טיגריס',
#  'Javanese': 'Macan',
#  'Kannada': 'ಹುಲಿ',
#  'Georgian': 'ვეფხვი',
#  'Kashmiri': 'شیر',
#  'Kashubian': 'Azjacczi tigris',
#  'Kazakh': 'Жолбарыс',
#  'Cornish': 'Tiger',
#  'Swahili': 'Chui milia',
#  'Kotava': 'Jaktol (Panthera tigris)',
#  'Haitian Creole': 'Tig',
#  'Kurdish': 'Piling (Panthera tigris)',
#  'Kyrgyz': 'Жолборс',
#  'Ladin': 'Tigra',
#  'Lak': 'Къаплан',
#  'Latgalian': 'Tygrys',
#  'Latin': 'Tigris',
#  'Latvian': 'Tīģeris',
#  'Luxembourgish': 'Tiger',
#  'Lezghian': 'Пеленг',
#  'Lithuanian': 'Tigras',
#  'Nias': 'Harimo',
#  'Limburgish': 'Tieger',
#  'Lingala': 'Nkɔi etáné',
#  'Lingua Franca Nova': 'Tigre',
#  'Lojban': 'tirxu',
#  'Lombard': 'Panthera tigris',
#  'Hungarian': 'Tigris (állat)',
#  'Maithili': 'बाघ',
#  'Macedonian': 'Тигар',
#  'Malagasy': 'Tigra',
#  'Malayalam': 'കടുവ',
#  'Māori': 'Taika',
#  'Marathi': 'वाघ',
#  'Mingrelian': 'ჸილო',
#  'Egyptian Arabic': 'نمر',
#  'Mazanderani': 'دورگ',
#  'Malay': 'Harimau',
#  'Manipuri': 'ꯀꯩ (ꯁꯥ)',
#  'Minangkabau': 'Harimau',
#  'Mindong': 'Lâu-hū',
#  'Moksha': 'Бабри',
#  'Mongolian': 'Бар',
#  'Burmese': 'ကျား',
#  'Dutch': 'Tijger',
#  'Nepali': 'बाघ',
#  'Newari': 'धुँ',
#  'Japanese': 'トラ',
#  'Chechen': 'ЦӀоькъалом',
#  'Northern Frisian': 'Tiiger',
#  'Norwegian': 'Tiger',
#  'Norwegian Nynorsk': 'Tiger',
#  'Occitan': 'Panthera tigris',
#  'Odia': 'ବାଘ',
#  'Oromo': 'Qeerransa',
#  'Uzbek': 'Yoʻlbars',
#  'Punjabi': 'ਸ਼ੇਰ',
#  'Western Punjabi': 'شیر',
#  'Pashto': 'پړانگ',
#  'Polish': 'Tygrys azjatycki',
#  'Portuguese': 'Tigre',
#  'Kara-Kalpak': 'Jolbarıs',
#  'Romanian': 'Tigru',
#  'Quechua': 'Tikri',
#  'Russian': 'Тигр',
#  'Yakut': 'Баабыр',
#  'Sakizaya': 'lukedaw',
#  'Samoan': 'Taika',
#  'Sanskrit': 'व्याघ्रः',
#  'Santali': 'ᱛᱟᱹᱨᱩᱵ',
#  'Saraiki': 'شیر',
#  'Scots': 'Teeger',
#  'Albanian': 'Tigri',
#  'Sicilian': 'Panthera tigris',
#  'Sinhala': 'ව්\u200dයාග්\u200dරයා',
#  'Simple English': 'Tiger',
#  'Slovak': 'Tiger džungľový',
#  'Slovenian': 'Tiger',
#  'Church Slavic': 'Тїгръ',
#  'Silesian': 'Panthera tigris',
#  'Somali': 'Shabeel',
#  'Central Kurdish': 'بەور',
#  'Serbian': 'Тигар',
#  'Serbo-Croatian': 'Tigar',
#  'Sundanese': 'Lodaya',
#  'Finnish': 'Tiikeri',
#  'Swedish': 'Tiger',
#  'Tagalog': 'Tigre',
#  'Tamil': 'புலி',
#  'Kabyle': 'Aksel (aɣersiw)',
#  'Tatar': 'Юлбарыс',
#  'Shan': 'သိူဝ်',
#  'Tayal': "kli'",
#  'Telugu': 'పులి',
#  'Thai': 'เสือโคร่ง',
#  'Tajik': 'Бабр',
#  'Cherokee': 'ᏢᏓᏥᏧᎶᎸᏗ',
#  'Tulu': 'ಪಿಲಿ',
#  'Turkish': 'Kaplan',
#  'Turkmen': 'Gaplaň',
#  'Twi': 'Sebɔ',
#  'Ukrainian': 'Тигр',
#  'Urdu': 'شیر',
#  'Uyghur': 'بارس',
#  'Zhuang': 'Guk',
#  'Veps': 'Tigr',
#  'Vietnamese': 'Hổ',
#  'Võro': 'Tiigri',
#  'Walloon': 'Tigue',
#  'Literary Chinese': '虎',
#  'Waray': 'Panthera tigris',
#  'Wolof': 'Segg',
#  'Wu': '虎',
#  'Yiddish': 'טיגער',
#  'Yoruba': 'Ẹkùn',
#  'Cantonese': '老虎',
#  'Chinese': '虎',
#  'Batak Toba': 'Babiat'}

# %%
tiger_lang["Finnish"]
# Out:
# 'Tiikeri'

# %% [markdown]
# ### Exercise 1.2

# %% [markdown]
# Find the HTML text within the structured data on the tiger page and assign it to a variable named ``htmlText``.

# %%
htmlText = tiger["parse"]["text"]["*"]

# %% [markdown]
# Convert the string to a BeautifulSoup object and assign it to a variable called ``tigerSoup``.

# %%
tigerSoup = BeautifulSoup(htmlText)

# %% [markdown]
# Repetitition: Extract (1) the first table and (2) the third paragraph of the article.

# %%
tigerSoup.find("table")
# Out:
# <table class="infobox biota" style="text-align: left; width: 200px; font-size: 100%">
# <tbody><tr>
# <th colspan="2" style="text-align: center; background-color: rgb(235,235,210)">Tiger<br/><div style="font-size: 85%;">Temporal range: <span class="noprint"><span style="display:inline-block;"></span><span style="display:inline-block;">Early Pleistocene – Present</span> <span style="display:inline-block;"></span><div id="Timeline-row" style="margin: 4px auto 0; clear:both; width:220px; padding:0px; height:18px; overflow:visible; white-space:nowrap; border:1px #666; border-style:solid none; position:relative; z-index:0; font-size:97%;">
# <div style="position:absolute; height:100%; left:0px; width:207.23076923077px; padding-left:5px; text-align:left; background-color:rgb(254,217,106); background-image: linear-gradient(to right, rgba(255,255,255,1), rgba(254,217,106,1) 15%, rgba(254,217,106,1));"><a href="/wiki/Precambrian" title="Precambrian">PreꞒ</a></div>
# <div style="position:absolute; height:100%; text-align:center; background-color:rgb(127,160,86); left:37.636923076923px; width:18.073846153846px;"><a href="/wiki/Cambrian" title="Cambrian">Ꞓ</a></div>
# <div style="position:absolute; height:100%; text-align:center; background-color:rgb(0,146,112); left:55.710769230769px; width:14.08px;"><a href="/wiki/Ordovician" title="Ordovician">O</a></div>
# <div style="position:absolute; height:100%; text-align:center; background-color:rgb(179,225,182); left:69.790769230769px; width:8.3261538461539px;"><a href="/wiki/Silurian" title="Silurian">S</a></div>
# <div style="position:absolute; height:100%; text-align:center; background-color:rgb(203,140,55); left:78.116923076923px; width:20.409230769231px;"><a href="/wiki/Devonian" title="Devonian">D</a></div>
# <div style="position:absolute; height:100%; text-align:center; background-color:rgb(103,165,153); left:98.526153846154px; width:20.307692307692px;"><a href="/wiki/Carboniferous" title="Carboniferous">C</a></div>
# <div style="position:absolute; height:100%; text-align:center; background-color:rgb(240,64,40); left:118.83384615385px; width:15.907015384615px;"><a href="/wiki/Permian" title="Permian">P</a></div>
# <div style="position:absolute; height:100%; text-align:center; background-color:rgb(129,43,146); left:134.74086153846px; width:17.092984615385px;"><a href="/wiki/Triassic" title="Triassic">T</a></div>
# <div style="position:absolute; height:100%; text-align:center; background-color:rgb(52,178,201); left:151.83384615385px; width:19.089230769231px;"><a href="/wiki/Jurassic" title="Jurassic">J</a></div>
# <div style="position:absolute; height:100%; text-align:center; background-color:rgb(127,198,78); left:170.92307692308px; width:26.738461538462px;"><a href="/wiki/Cretaceous" title="Cretaceous">K</a></div>
# <div style="position:absolute; height:100%; text-align:center; background-color:rgb(253,154,82); left:197.66153846154px; width:14.543692307692px;"><a href="/wiki/Paleogene" title="Paleogene">Pg</a></div>
# <div style="position:absolute; height:100%; text-align:center; background-color:rgb(255,230,25); left:212.20523076923px; width:6.9215384615385px;"><a href="/wiki/Neogene" title="Neogene">N</a></div>
# <div id="end-border" style="position:absolute; height:100%; background-color:#666; width:1px; left:219px"></div><div style="margin:0 auto; line-height:0; clear:both; width:220px; padding:0px; height:8px; overflow:visible; background-color:transparent; position:relative; top:-4px; z-index:100;">
# <div style="position:absolute; left:219.12676923077px; font-size:50%"><div style="position:relative; left:-0.42em">↓</div></div>
# </div>
# </div></span></div>
# </th></tr>
# <tr>
# <td colspan="2" style="text-align: center"><span class="mw-default-size" typeof="mw:File/Frameless"><a class="mw-file-description" href="/wiki/File:Walking_tiger_female.jpg"><img class="mw-file-element" data-file-height="1969" data-file-width="3569" decoding="async" height="143" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/3f/Walking_tiger_female.jpg/260px-Walking_tiger_female.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/3f/Walking_tiger_female.jpg/390px-Walking_tiger_female.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/3/3f/Walking_tiger_female.jpg/520px-Walking_tiger_female.jpg 2x" width="260"/></a></span>
# </td></tr>
# <tr>
# <td colspan="2" style="text-align: center; font-size: 88%">A <a href="/wiki/Bengal_tiger" title="Bengal tiger">Bengal tigress</a> in <a href="/wiki/Kanha_Tiger_Reserve" title="Kanha Tiger Reserve">Kanha Tiger Reserve</a>, India
# </td></tr>
# <tr style="text-align: center; background-color: rgb(235,235,210)">
# <th colspan="2"><div style="text-align: center"><a href="/wiki/Conservation_status" title="Conservation status">Conservation status</a></div>
# </th></tr>
# <tr>
# <td colspan="2"><div style="text-align: center"><span class="mw-default-size skin-invert-image" typeof="mw:File/Frameless"><span><img alt="" class="mw-file-element" data-file-height="137" data-file-width="512" decoding="async" height="59" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/70/Status_iucn3.1_EN.svg/220px-Status_iucn3.1_EN.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/70/Status_iucn3.1_EN.svg/330px-Status_iucn3.1_EN.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/70/Status_iucn3.1_EN.svg/440px-Status_iucn3.1_EN.svg.png 2x" width="220"/></span></span><br/><a href="/wiki/Endangered_species_(IUCN_status)" title="Endangered species (IUCN status)">Endangered</a> <small> (<a href="/wiki/IUCN_Red_List" title="IUCN Red List">IUCN 3.1</a>)<sup class="reference" id="cite_ref-iucn_1-0"><a href="#cite_note-iucn-1"><span class="cite-bracket">[</span>1<span class="cite-bracket">]</span></a></sup></small></div>
# </td></tr>
# <tr>
# <td colspan="2"><div style="text-align: center"><a href="/wiki/CITES" title="CITES">CITES</a> Appendix I<small> (<a href="/wiki/CITES" title="CITES">CITES</a>)<sup class="reference" id="cite_ref-iucn_1-1"><a href="#cite_note-iucn-1"><span class="cite-bracket">[</span>1<span class="cite-bracket">]</span></a></sup></small></div>
# </td></tr>
# <tr>
# <th colspan="2" style="min-width:15em; text-align: center; background-color: rgb(235,235,210)"><a href="/wiki/Taxonomy_(biology)" title="Taxonomy (biology)">Scientific classification</a> <span class="plainlinks taxobox-edit-taxonomy skin-invert" style="font-size:smaller; float:right; padding-right:0.4em; margin-left:-3em;"><span typeof="mw:File"><a href="/wiki/Template:Taxonomy/Panthera" title="Edit this classification"><img alt="Edit this classification" class="mw-file-element" data-file-height="20" data-file-width="20" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/8a/OOjs_UI_icon_edit-ltr.svg/15px-OOjs_UI_icon_edit-ltr.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/8a/OOjs_UI_icon_edit-ltr.svg/23px-OOjs_UI_icon_edit-ltr.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/8/8a/OOjs_UI_icon_edit-ltr.svg/30px-OOjs_UI_icon_edit-ltr.svg.png 2x" width="15"/></a></span></span>
# </th></tr>
# <tr>
# <td>Domain:
# </td>
# <td><a href="/wiki/Eukaryote" title="Eukaryote">Eukaryota</a>
# </td></tr>
# <tr>
# <td>Kingdom:
# </td>
# <td><a href="/wiki/Animal" title="Animal">Animalia</a>
# </td></tr>
# <tr>
# <td>Phylum:
# </td>
# <td><a href="/wiki/Chordate" title="Chordate">Chordata</a>
# </td></tr>
# <tr>
# <td>Class:
# </td>
# <td><a href="/wiki/Mammal" title="Mammal">Mammalia</a>
# </td></tr>
# <tr>
# <td>Order:
# </td>
# <td><a href="/wiki/Carnivora" title="Carnivora">Carnivora</a>
# </td></tr>
# <tr>
# <td>Suborder:
# </td>
# <td><a href="/wiki/Feliformia" title="Feliformia">Feliformia</a>
# </td></tr>
# <tr>
# <td>Family:
# </td>
# <td><a href="/wiki/Felidae" title="Felidae">Felidae</a>
# </td></tr>
# <tr>
# <td>Subfamily:
# </td>
# <td><a href="/wiki/Pantherinae" title="Pantherinae">Pantherinae</a>
# </td></tr>
# <tr>
# <td>Genus:
# </td>
# <td><a href="/wiki/Panthera" title="Panthera"><i>Panthera</i></a>
# </td></tr>
# <tr>
# <td>Species:
# </td>
# <td><div class="species" style="display:inline"><i><b>P. tigris</b></i></div>
# </td></tr>
# <tr>
# <th colspan="2" style="text-align: center; background-color: rgb(235,235,210)"><a href="/wiki/Binomial_nomenclature" title="Binomial nomenclature">Binomial name</a>
# </th></tr>
# <tr>
# <td colspan="2" style="text-align: center"><b><span class="binomial"><span style="font-weight:normal;"></span><i>Panthera tigris</i></span></b><br/><div style="font-size: 85%;">(<a href="/wiki/Carl_Linnaeus" title="Carl Linnaeus">Linnaeus</a>, 1758)<sup class="reference" id="cite_ref-Linn1758_2-0"><a href="#cite_note-Linn1758-2"><span class="cite-bracket">[</span>2<span class="cite-bracket">]</span></a></sup></div>
# </td></tr>
# <tr>
# <th colspan="2" style="text-align: center; background-color: rgb(235,235,210)">Subspecies
# </th></tr>
# <tr>
# <td colspan="2" style="text-align: left">
# <ul><li><i><a class="mw-redirect" href="/wiki/Panthera_tigris_tigris" title="Panthera tigris tigris">P. t. tigris</a></i></li>
# <li><i><a class="mw-redirect" href="/wiki/Sunda_Island_tiger" title="Sunda Island tiger">P. t. sondaica</a></i></li>
# <li><abbr aria-label="Extinct" style="border: none; text-decoration: none; cursor: inherit; font-weight: normal; font-style: normal;" title="Extinct">†</abbr><i><a href="/wiki/Panthera_tigris_acutidens" title="Panthera tigris acutidens">P. t. acutidens</a></i></li>
# <li><abbr aria-label="Extinct" style="border: none; text-decoration: none; cursor: inherit; font-weight: normal; font-style: normal;" title="Extinct">†</abbr><i><a href="/wiki/Panthera_tigris_soloensis" title="Panthera tigris soloensis">P. t. soloensis</a></i></li>
# <li><abbr aria-label="Extinct" style="border: none; text-decoration: none; cursor: inherit; font-weight: normal; font-style: normal;" title="Extinct">†</abbr><i><a href="/wiki/Panthera_tigris_trinilensis" title="Panthera tigris trinilensis">P. t. trinilensis</a></i></li></ul>
# </td></tr>
# <tr>
# <td colspan="2" style="text-align: center"><span class="mw-default-size" typeof="mw:File/Frameless"><a class="mw-file-description" href="/wiki/File:Tiger_distribution.png"><img class="mw-file-element" data-file-height="1150" data-file-width="1750" decoding="async" height="171" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Tiger_distribution.png/260px-Tiger_distribution.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Tiger_distribution.png/390px-Tiger_distribution.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Tiger_distribution.png/520px-Tiger_distribution.png 2x" width="260"/></a></span>
# </td></tr>
# <tr>
# <td colspan="2" style="text-align: center; font-size: 88%">Tiger distribution as of 2022
# </td></tr>
# <tr>
# <th colspan="2" style="text-align: center; background-color: rgb(235,235,210)"><a href="/wiki/Synonym_(taxonomy)" title="Synonym (taxonomy)">Synonyms</a><sup class="reference" id="cite_ref-3"><a href="#cite_note-3"><span class="cite-bracket">[</span>3<span class="cite-bracket">]</span></a></sup>
# </th></tr>
# <tr>
# <td colspan="2" style="text-align: left">
# <ul class="taxonlist"><li><i>Felis tigris</i> <small> <a href="/wiki/Carl_Linnaeus" title="Carl Linnaeus">Linnaeus</a>, <a href="/wiki/Systema_Naturae" title="Systema Naturae">1758</a>
# </small></li><li><i>Tigris striatus</i> <small> <a href="/wiki/Nikolai_Severtzov" title="Nikolai Severtzov">Severtzov</a>, 1858
# </small></li><li><i>Tigris regalis</i> <small> <a href="/wiki/John_Edward_Gray" title="John Edward Gray">Gray</a>, 1867
# </small></li></ul>
# </td></tr>
# </tbody></table>

# %%
tigerSoup.find_all("p")[2]
# Out:
# <p>Throughout the tiger's range, it inhabits mainly forests, from <a href="/wiki/Conifer" title="Conifer">coniferous</a> and <a class="mw-redirect" href="/wiki/Temperate_broadleaf_and_mixed_forest" title="Temperate broadleaf and mixed forest">temperate broadleaf and mixed forests</a> in the <a href="/wiki/Russian_Far_East" title="Russian Far East">Russian Far East</a> and <a href="/wiki/Northeast_China" title="Northeast China">Northeast China</a> to <a href="/wiki/Tropical_and_subtropical_moist_broadleaf_forests" title="Tropical and subtropical moist broadleaf forests">tropical and subtropical moist broadleaf forests</a> on the <a href="/wiki/Indian_subcontinent" title="Indian subcontinent">Indian subcontinent</a> and <a href="/wiki/Southeast_Asia" title="Southeast Asia">Southeast Asia</a>. The tiger is an <a href="/wiki/Apex_predator" title="Apex predator">apex predator</a> and preys mainly on <a href="/wiki/Ungulate" title="Ungulate">ungulates</a>, which it takes by ambush. It lives a mostly solitary life and occupies <a href="/wiki/Home_range" title="Home range">home ranges</a>, defending these from individuals of the same sex. The range of a male tiger overlaps with that of multiple females with whom he mates. Females give birth to usually two or three cubs that stay with their mother for about two years. When becoming independent, they leave their mother's home range and establish their own.
# </p>

# %% [markdown]
# ### Exercise 1.3

# %% [markdown]
# Retrieve the information about 10 Wikipedia pages that match with the word "tiger" and convert the response to a dictionary. ><font color='violet'> Hint: <font color='white'> Hint: The "srlimit" parameter allows you to specify how many pages you want to retrieve.

# %%
# Perform page search
URL = "https://en.wikipedia.org/w/api.php"

PARAMS = {
    "action": "query",
    "format": "json",
    "list": "search",
    "srsearch": "tiger",
    "srlimit": 10
}

r = requests.get(url=URL, params=PARAMS)

# Convert to dictionary
tigers = r.json()

# %% [markdown]
# Navigate through the dictionary or type the URL into your browser to inspect how the data is structured.

# %%
# Get URL so you can explore the structure of the data in your Browser
r.url
# Out:
# 'https://en.wikipedia.org/w/api.php?action=query&format=json&list=search&srsearch=tiger&srlimit=10'

# %%
# Explore the dictionary
print(tigers.keys())
print(tigers["query"].keys())
type(tigers["query"]["search"]) # tigers["query"]["search"] contains a list of dictionaries!
# Out:
# dict_keys(['batchcomplete', 'continue', 'query'])
# dict_keys(['searchinfo', 'search'])
# list

# %% [markdown]
# Now print out the titles of the 10 tiger pages.

# %%
# Extract titles
tiger_pages = tigers["query"]["search"]

[elem["title"] for elem in tiger_pages]
# Out:
# ['Tiger',
#  'Topologically Integrated Geographic Encoding and Referencing',
#  'Tiger Tiger',
#  'Tiger Woods',
#  'Tiger (zodiac)',
#  'Tiger 3',
#  'Siberian tiger',
#  'Bengal tiger',
#  'Tiger I',
#  'Tiger II']

# %% [markdown]
# ### Exercise 1.4

# %% [markdown]
# In the web scraping exercises, you wrote a simple scraper that fetched you some information from the following animal pages:

# %%
animals = ["Cat", "Dog", "Tiger", "Giant_panda"]

# %% [markdown]
# You will now try to do the same using the API: Write a loop that fetches all the pages and retrieves (1) the title and (2) the number of images on each page.

# %% [markdown]
# Let's do this step by step. First try to fetch the "Cat" page and convert the JSON response you get into a Python dictionary.

# %%
URL = "https://en.wikipedia.org/w/api.php"

PARAMS = {
    "action": "parse",
    "page": "Cat",
    "format": "json",
}

r = requests.get(url=URL, params=PARAMS)
data = r.json()

# %% [markdown]
# Now try to retrieve the title and the number of images. Assign each of them to a variable.

# %%
title = data["parse"]["title"]
images = len(data["parse"]["images"])
print(title, images)
# Out:
# Cat 59

# %% [markdown]
# Now write a loop that fetches all the pages and writes the response into a list. You will have to create an empty list and ``append`` the new elements to it:

# %%
L = []
for pagename in animals:
  URL = "https://en.wikipedia.org/w/api.php"

  PARAMS = {
        "action": "parse",
        "page": pagename,
        "format": "json",
        }

  r = requests.get(url=URL, params=PARAMS)
  L.append(r)

L
# Out:
# [<Response [200]>, <Response [200]>, <Response [200]>, <Response [200]>]

# %% [markdown]
# Finally, you can bring everything together. Improve your loop so that it parses each page, retrieves the title and the number of images and writes them into a nested list.

# %%
L = []
for pagename in animals:
  URL = "https://en.wikipedia.org/w/api.php"

  PARAMS = {
        "action": "parse",
        "page": pagename,
        "format": "json",
        }

  r = requests.get(url=URL, params=PARAMS)
  data = r.json()

  title = data["parse"]["title"]
  images = len(data["parse"]["images"])

  L.append([title, images])

L
# Out:
# [['Cat', 59], ['Dog', 47], ['Tiger', 63], ['Giant panda', 25]]

# %% [markdown]
# ## 2. Advanced exercises*

# %% [markdown]
# ---
#
#
# <font color='red'>
# *Feel free to skip the advanced exercises if you feel overwhelmed or if trying to solve the basic exercises already took you a lot of time!
#
#
# ---

# %% [markdown]
# ### Exercise 2.1

# %% [markdown]
# Write a function called ``getWiki`` that allows you to enter the name of a Wikipedia page and returns the parsed JSON response as a Python dictionary.

# %%
def getWiki(pagename):
  ENDPOINT = "https://en.wikipedia.org/w/api.php"

  PARAMS = {
      "action": "parse",
      "page": pagename,
      "format": "json",
  }

  r = requests.get(url=ENDPOINT, params=PARAMS)
  return r.json()

# %%
getWiki("Python")
# Out:
# {'parse': {'title': 'Python',
#   'pageid': 46332325,
#   'revid': 1233294168,
#   'text': {'*': '<div class="mw-content-ltr mw-parser-output" lang="en" dir="ltr"><style data-mw-deduplicate="TemplateStyles:r1235681985">.mw-parser-output .side-box{margin:4px 0;box-sizing:border-box;border:1px solid #aaa;font-size:88%;line-height:1.25em;background-color:var(--background-color-interactive-subtle,#f8f9fa);display:flow-root}.mw-parser-output .side-box-abovebelow,.mw-parser-output .side-box-text{padding:0.25em 0.9em}.mw-parser-output .side-box-image{padding:2px 0 2px 0.9em;text-align:center}.mw-parser-output .side-box-imageright{padding:2px 0.9em 2px 0;text-align:center}@media(min-width:500px){.mw-parser-output .side-box-flex{display:flex;align-items:center}.mw-parser-output .side-box-text{flex:1;min-width:0}}@media(min-width:720px){.mw-parser-output .side-box{width:238px}.mw-parser-output .side-box-right{clear:right;float:right;margin-left:1em}.mw-parser-output .side-box-left{margin-right:1em}}</style><style data-mw-deduplicate="TemplateStyles:r1236082730">@media print{body.ns-0 .mw-parser-output .sistersitebox{display:none!important}}</style><div class="side-box side-box-right plainlinks sistersitebox"><style data-mw-deduplicate="TemplateStyles:r1126788409">.mw-parser-output .plainlist ol,.mw-parser-output .plainlist ul{line-height:inherit;list-style:none;margin:0;padding:0}.mw-parser-output .plainlist ol li,.mw-parser-output .plainlist ul li{margin-bottom:0}</style>\n<div class="side-box-flex">\n<div class="side-box-image"><span class="noviewer" typeof="mw:File"><span><img alt="" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/99/Wiktionary-logo-en-v2.svg/40px-Wiktionary-logo-en-v2.svg.png" decoding="async" width="40" height="40" class="mw-file-element" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/99/Wiktionary-logo-en-v2.svg/60px-Wiktionary-logo-en-v2.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/99/Wiktionary-logo-en-v2.svg/80px-Wiktionary-logo-en-v2.svg.png 2x" data-file-width="512" data-file-height="512" /></span></span></div>\n<div class="side-box-text plainlist">Look up <i><b><a href="https://en.wiktionary.org/wiki/Python" class="extiw" title="wiktionary:Python">Python</a></b></i>&#160;or <i><b><a href="https://en.wiktionary.org/wiki/python" class="extiw" title="wiktionary:python">python</a></b></i> in Wiktionary, the free dictionary.</div></div>\n</div>\n<p><b>Python</b> may refer to:\n</p>\n<style data-mw-deduplicate="TemplateStyles:r1044870489">@media all and (max-width:720px){body.skin-minerva .mw-parser-output .tocright{display:none}.mw-parser-output .tocright{width:100%!important}}@media all and (min-width:720px){.mw-parser-output .tocright{float:right;clear:right;width:auto;margin:0 0 0.5em 1em}.mw-parser-output .tocright-clear-left{clear:left}.mw-parser-output .tocright-clear-both{clear:both}.mw-parser-output .tocright-clear-none{clear:none}}</style><div class="tocright"><meta property="mw:PageProp/toc" /></div>\n<div class="mw-heading mw-heading2"><h2 id="Snakes">Snakes</h2><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Python&amp;action=edit&amp;section=1" title="Edit section: Snakes"><span>edit</span></a><span class="mw-editsection-bracket">]</span></span></div>\n<ul><li><a href="/wiki/Pythonidae" title="Pythonidae">Pythonidae</a>, a family of nonvenomous snakes found in Africa, Asia, and Australia\n<ul><li><a href="/wiki/Python_(genus)" title="Python (genus)"><i>Python</i> (genus)</a>, a genus of Pythonidae found in Africa and Asia</li></ul></li>\n<li><a href="/wiki/Python_(mythology)" title="Python (mythology)">Python (mythology)</a>, a mythical serpent</li></ul>\n<div class="mw-heading mw-heading2"><h2 id="Computing">Computing</h2><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Python&amp;action=edit&amp;section=2" title="Edit section: Computing"><span>edit</span></a><span class="mw-editsection-bracket">]</span></span></div>\n<ul><li><a href="/wiki ...
#   'langlinks': [{'lang': 'af',
#     'url': 'https://af.wikipedia.org/wiki/Python',
#     'langname': 'Afrikaans',
#     'autonym': 'Afrikaans',
#     '*': 'Python'},
#    {'lang': 'als',
#     'url': 'https://als.wikipedia.org/wiki/Python',
#     'langname': 'Alemannic',
#     'autonym': 'Alemannisch',
#     '*': 'Python'},
#    {'lang': 'ar',
#     'url': 'https://ar.wikipedia.org/wiki/%D8%A8%D8%A7%D9%8A%D8%AB%D9%88%D9%86_(%D8%AA%D9%88%D8%B6%D9%8A%D8%AD)',
#     'langname': 'Arabic',
#     'autonym': 'العربية',
#     '*': 'بايثون (توضيح)'},
#    {'lang': 'az',
#     'url': 'https://az.wikipedia.org/wiki/Python_(d%C9%99qiql%C9%99%C5%9Fdirm%C9%99)',
#     'langname': 'Azerbaijani',
#     'autonym': 'azərbaycanca',
#     '*': 'Python (dəqiqləşdirmə)'},
#    {'lang': 'bn',
#     'url': 'https://bn.wikipedia.org/wiki/%E0%A6%AA%E0%A6%BE%E0%A6%87%E0%A6%A5%E0%A6%A8_(%E0%A6%A6%E0%A7%8D%E0%A6%AC%E0%A7%8D%E0%A6%AF%E0%A6%B0%E0%A7%8D%E0%A6%A5%E0%A6%A4%E0%A6%BE_%E0%A6%A8%E0%A6%BF%E0%A6%B0%E0%A6%B8%E0%A6%A8)',
#     'langname': 'Bangla',
#     'autonym': 'বাংলা',
#     '*': 'পাইথন (দ্ব্যর্থতা নিরসন)'},
#    {'lang': 'be',
#     'url': 'https://be.wikipedia.org/wiki/Python',
#     'langname': 'Belarusian',
#     'autonym': 'беларуская',
#     '*': 'Python'},
#    {'lang': 'bg',
#     'url': 'https://bg.wikipedia.org/wiki/%D0%9F%D0%B8%D1%82%D0%BE%D0%BD_(%D0%BF%D0%BE%D1%8F%D1%81%D0%BD%D0%B5%D0%BD%D0%B8%D0%B5)',
#     'langname': 'Bulgarian',
#     'autonym': 'български',
#     '*': 'Питон (пояснение)'},
#    {'lang': 'cs',
#     'url': 'https://cs.wikipedia.org/wiki/Python_(rozcestn%C3%ADk)',
#     'langname': 'Czech',
#     'autonym': 'čeština',
#     '*': 'Python (rozcestník)'},
#    {'lang': 'da',
#     'url': 'https://da.wikipedia.org/wiki/Python',
#     'langname': 'Danish',
#     'autonym': 'dansk',
#     '*': 'Python'},
#    {'lang': 'de',
#     'url': 'https://de.wikipedia.org/wiki/Python',
#     'langname': 'German',
#     'autonym': 'Deutsch',
#     '*': 'Python'},
#    {'lang': 'eo',
#     'url': 'https://eo.wikipedia.org/wiki/Pitono_(apartigilo)',
#     'langname': 'Esperanto',
#     'autonym': 'Esperanto',
#     '*': 'Pitono (apartigilo)'},
#    {'lang': 'eu',
#     'url': 'https://eu.wikipedia.org/wiki/Python_(argipena)',
#     'langname': 'Basque',
#     'autonym': 'euskara',
#     '*': 'Python (argipena)'},
#    {'lang': 'fa',
#     'url': 'https://fa.wikipedia.org/wiki/%D9%BE%D8%A7%DB%8C%D8%AA%D9%88%D9%86',
#     'langname': 'Persian',
#     'autonym': 'فارسی',
#     '*': 'پایتون'},
#    {'lang': 'fr',
#     'url': 'https://fr.wikipedia.org/wiki/Python',
#     'langname': 'French',
#     'autonym': 'français',
#     '*': 'Python'},
#    {'lang': 'ko',
#     'url': 'https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%84%A0',
#     'langname': 'Korean',
#     'autonym': '한국어',
#     '*': '파이선'},
#    {'lang': 'hr',
#     'url': 'https://hr.wikipedia.org/wiki/Python_(razdvojba)',
#     'langname': 'Croatian',
#     'autonym': 'hrvatski',
#     '*': 'Python (razdvojba)'},
#    {'lang': 'io',
#     'url': 'https://io.wikipedia.org/wiki/Pitono',
#     'langname': 'Ido',
#     'autonym': 'Ido',
#     '*': 'Pitono'},
#    {'lang': 'id',
#     'url': 'https://id.wikipedia.org/wiki/Python',
#     'langname': 'Indonesian',
#     'autonym': 'Bahasa Indonesia',
#     '*': 'Python'},
#    {'lang': 'ia',
#     'url': 'https://ia.wikipedia.org/wiki/Python_(disambiguation)',
#     'langname': 'Interlingua',
#     'autonym': 'interlingua',
#     '*': 'Python (disambiguation)'},
#    {'lang': 'is',
#     'url': 'https://is.wikipedia.org/wiki/Python_(a%C3%B0greining)',
#     'langname': 'Icelandic',
#     'autonym': 'íslenska',
#     '*': 'Python (aðgreining)'},
#    {'lang': 'it',
#     'url': 'https://it.wikipedia.org/wiki/Python_(disambigua)',
#     'langname': 'Italian',
#     'autonym': 'italiano',
#     '*': 'Python (disambigua)'},
#    {'lang': 'he',
#     'url': 'https://he.wikipedia.org/wiki/%D7%A4%D7%99%D7%AA%D7%95%D7%9F',
#     'langname': 'Hebrew',
#     'autonym': 'עברית',
#     '*': 'פיתון'},
#    {'lang': 'kn',
#     'url': 'https://kn.wikipedia.org/wiki/%E0%B2%B9%E0%B3%86%E0%B2%AC%E0%B3%8D%E0%B2%AC%E0%B2%BE%E0%B2%B5%E0%B3%81',
#     'langname': 'Kannada',
#     'autonym': 'ಕನ್ನಡ',
#     '*': 'ಹೆಬ್ಬಾವು'},
#    {'lang': 'ka',
#     'url': 'https://ka.wikipedia.org/wiki/%E1%83%9E%E1%83%98%E1%83%97%E1%83%9D%E1%83%9C%E1%83%98_(%E1%83%9B%E1%83%A0%E1%83%90%E1%83%95%E1%83%90%E1%83%9A%E1%83%9B%E1%83%9C%E1%83%98%E1%83%A8%E1%83%95%E1%83%9C%E1%83%94%E1%83%9A%E1%83%9D%E1%83%95%E1%83%90%E1%83%9C%E1%83%98)',
#     'langname': 'Georgian',
#     'autonym': 'ქართული',
#     '*': 'პითონი (მრავალმნიშვნელოვანი)'},
#    {'lang': 'kg',
#     'url': 'https://kg.wikipedia.org/wiki/Mboma_(nyoka)',
#     'langname': 'Kongo',
#     'autonym': 'Kongo',
#     '*': 'Mboma (nyoka)'},
#    {'lang': 'la',
#     'url': 'https://la.wikipedia.org/wiki/Python_(discretiva)',
#     'langname': 'Latin',
#     'autonym': 'Latina',
#     '*': 'Python (discretiva)'},
#    {'lang': 'lb',
#     'url': 'https://lb.wikipedia.org/wiki/Python',
#     'langname': 'Luxembourgish',
#     'autonym': 'Lëtzebuergesch',
#     '*': 'Python'},
#    {'lang': 'hu',
#     'url': 'https://hu.wikipedia.org/wiki/Python_(egy%C3%A9rtelm%C5%B1s%C3%ADt%C5%91_lap)',
#     'langname': 'Hungarian',
#     'autonym': 'magyar',
#     '*': 'Python (egyértelműsítő lap)'},
#    {'lang': 'mr',
#     'url': 'https://mr.wikipedia.org/wiki/%E0%A4%AA%E0%A4%BE%E0%A4%AF%E0%A4%A5%E0%A5%89%E0%A4%A8_(%E0%A4%86%E0%A4%9C%E0%A5%8D%E0%A4%9E%E0%A4%BE%E0%A4%B5%E0%A4%B2%E0%A5%80_%E0%A4%AD%E0%A4%BE%E0%A4%B7%E0%A4%BE)',
#     'langname': 'Marathi',
#     'autonym': 'मराठी',
#     '*': 'पायथॉन (आज्ञावली भाषा)'},
#    {'lang': 'nl',
#     'url': 'https://nl.wikipedia.org/wiki/Python',
#     'langname': 'Dutch',
#     'autonym': 'Nederlands',
#     '*': 'Python'},
#    {'lang': 'ja',
#     'url': 'https://ja.wikipedia.org/wiki/%E3%83%91%E3%82%A4%E3%82%BD%E3%83%B3',
#     'langname': 'Japanese',
#     'autonym': '日本語',
#     '*': 'パイソン'},
#    {'lang': 'no',
#     'url': 'https://no.wikipedia.org/wiki/Pyton',
#     'langname': 'Norwegian',
#     'autonym': 'norsk',
#     '*': 'Pyton'},
#    {'lang': 'pl',
#     'url': 'https://pl.wikipedia.org/wiki/Pyton',
#     'langname': 'Polish',
#     'autonym': 'polski',
#     '*': 'Pyton'},
#    {'lang': 'pt',
#     'url': 'https://pt.wikipedia.org/wiki/Python_(desambigua%C3%A7%C3%A3o)',
#     'langname': 'Portuguese',
#     'autonym': 'português',
#     '*': 'Python (desambiguação)'},
#    {'lang': 'ru',
#     'url': 'https://ru.wikipedia.org/wiki/Python_(%D0%B7%D0%BD%D0%B0%D1%87%D0%B5%D0%BD%D0%B8%D1%8F)',
#     'langname': 'Russian',
#     'autonym': 'русский',
#     '*': 'Python (значения)'},
#    {'lang': 'sk',
#     'url': 'https://sk.wikipedia.org/wiki/Python',
#     'langname': 'Slovak',
#     'autonym': 'slovenčina',
#     '*': 'Python'},
#    {'lang': 'sr',
#     'url': 'https://sr.wikipedia.org/wiki/%D0%9F%D0%B8%D1%82%D0%BE%D0%BD_(%D0%B2%D0%B8%D1%88%D0%B5%D0%B7%D0%BD%D0%B0%D1%87%D0%BD%D0%B0_%D0%BE%D0%B4%D1%80%D0%B5%D0%B4%D0%BD%D0%B8%D1%86%D0%B0)',
#     'langname': 'Serbian',
#     'autonym': 'српски / srpski',
#     '*': 'Питон (вишезначна одредница)'},
#    {'lang': 'sh',
#     'url': 'https://sh.wikipedia.org/wiki/Python',
#     'langname': 'Serbo-Croatian',
#     'autonym': 'srpskohrvatski / српскохрватски',
#     '*': 'Python'},
#    {'lang': 'fi',
#     'url': 'https://fi.wikipedia.org/wiki/Python',
#     'langname': 'Finnish',
#     'autonym': 'suomi',
#     '*': 'Python'},
#    {'lang': 'sv',
#     'url': 'https://sv.wikipedia.org/wiki/Pyton',
#     'langname': 'Swedish',
#     'autonym': 'svenska',
#     '*': 'Pyton'},
#    {'lang': 'th',
#     'url': 'https://th.wikipedia.org/wiki/%E0%B9%84%E0%B8%9E%E0%B8%97%E0%B8%AD%E0%B8%99',
#     'langname': 'Thai',
#     'autonym': 'ไทย',
#     '*': 'ไพทอน'},
#    {'lang': 'tr',
#     'url': 'https://tr.wikipedia.org/wiki/Python_(anlam_ayr%C4%B1m%C4%B1)',
#     'langname': 'Turkish',
#     'autonym': 'Türkçe',
#     '*': 'Python (anlam ayrımı)'},
#    {'lang': 'uk',
#     'url': 'https://uk.wikipedia.org/wiki/%D0%9F%D1%96%D1%84%D0%BE%D0%BD',
#     'langname': 'Ukrainian',
#     'autonym': 'українська',
#     '*': 'Піфон'},
#    {'lang': 'ur',
#     'url': 'https://ur.wikipedia.org/wiki/%D9%BE%D8%A7%D8%A6%DB%8C%D8%AA%DA%BE%D9%88%D9%86',
#     'langname': 'Urdu',
#     'autonym': 'اردو',
#     '*': 'پائیتھون'},
#    {'lang': 'vi',
#     'url': 'https://vi.wikipedia.org/wiki/Python',
#     'langname': 'Vietnamese',
#     'autonym': 'Tiếng Việt',
#     '*': 'Python'},
#    {'lang': 'zh',
#     'url': 'https://zh.wikipedia.org/wiki/Python_(%E6%B6%88%E6%AD%A7%E4%B9%89)',
#     'langname': 'Chinese',
#     'autonym': '中文',
#     '*': 'Python (消歧义)'}],
#   'categories': [{'sortkey': '',
#     'hidden': '',
#     '*': 'Short_description_is_different_from_Wikidata'},
#    {'sortkey': '', 'hidden': '', '*': 'All_article_disambiguation_pages'},
#    {'sortkey': '', 'hidden': '', '*': 'All_disambiguation_pages'},
#    {'sortkey': '', '*': 'Disambiguation_pages'},
#    {'sortkey': '', '*': 'Human_name_disambiguation_pages'},
#    {'sortkey': '', '*': 'Disambiguation_pages_with_given-name-holder_lists'},
#    {'sortkey': '',
#     'hidden': '',
#     '*': 'Animal_common_name_disambiguation_pages'}],
#   'links': [{'ns': 1, 'exists': '', '*': 'Talk:Python'},
#    {'ns': 0, 'exists': '', '*': 'CMU Common Lisp'},
#    {'ns': 0, 'exists': '', '*': 'Colt Python'},
#    {'ns': 0, 'exists': '', '*': 'Monty Python'},
#    {'ns': 0, 'exists': '', '*': 'PERQ'},
#    {'ns': 0, 'exists': '', '*': 'Pithon'},
#    {'ns': 0, 'exists': '', '*': 'Python (Busch Gardens Tampa Bay)'},
#    {'ns': 0, 'exists': '', '*': 'Python (Coney Island, Cincinnati, Ohio)'},
#    {'ns': 0, 'exists': '', '*': 'Python (Efteling)'},
#    {'ns': 0, 'exists': '', '*': 'Python (Ford prototype)'},
#    {'ns': 0, 'exists': '', '*': 'Python (Monty) Pictures'},
#    {'ns': 0, 'exists': '', '*': 'Python (automobile maker)'},
#    {'ns': 0, 'exists': '', '*': 'Python (codename)'},
#    {'ns': 0, 'exists': '', '*': 'Python (film)'},
#    {'ns': 0, 'exists': '', '*': 'Python (genus)'},
#    {'ns': 0, 'exists': '', '*': 'Python (missile)'},
#    {'ns': 0, 'exists': '', '*': 'Python (mythology)'},
#    {'ns': 0, 'exists': '', '*': 'Python (nuclear primary)'},
#    {'ns': 0, 'exists': '', '*': 'Python (painter)'},
#    {'ns': 0, 'exists': '', '*': 'Python (programming language)'},
#    {'ns': 0, 'exists': '', '*': 'Python Anghelo'},
#    {'ns': 0, 'exists': '', '*': 'Python of Aenus'},
#    {'ns': 0, 'exists': '', '*': 'Python of Byzantium'},
#    {'ns': 0, 'exists': '', '*': 'Python of Catana'},
#    {'ns': 0, 'exists': '', '*': 'Pythonidae'},
#    {'ns': 0, 'exists': '', '*': 'Pyton'},
#    {'ns': 0, 'exists': '', '*': 'Timon of Phlius'},
#    {'ns': 12, 'exists': '', '*': 'Help:Disambiguation'}],
#   'templates': [{'ns': 10, 'exists': '', '*': 'Template:Wiktionary'},
#    {'ns': 10, 'exists': '', '*': 'Template:Sister project'},
#    {'ns': 10, 'exists': '', '*': 'Template:Side box'},
#    {'ns': 10, 'exists': '', '*': 'Template:Plainlist/styles.css'},
#    {'ns': 10, 'exists': '', '*': 'Template:Sister project/styles.css'},
#    {'ns': 10, 'exists': '', '*': 'Template:TOC right'},
#    {'ns': 10, 'exists': '', '*': 'Template:TOC right/styles.css'},
#    {'ns': 10, 'exists': '', '*': 'Template:Disambiguation'},
#    {'ns': 10,
#     'exists': '',
#     '*': 'Template:Disambiguation page short description'},
#    {'ns': 10, 'exists': '', '*': 'Template:Short description'},
#    {'ns': 10, 'exists': '', '*': 'Template:Main other'},
#    {'ns': 10, 'exists': '', '*': 'Template:Short description/lowercasecheck'},
#    {'ns': 10, 'exists': '', '*': 'Template:SDcat'},
#    {'ns': 10, 'exists': '', '*': 'Template:Dmbox'},
#    {'ns': 10, 'exists': '', '*': 'Template:Dmbox/styles.css'},
#    {'ns': 10, 'exists': '', '*': 'Template:Title disambig text'},
#    {'ns': 10, 'exists': '', '*': 'Template:Str rep'},
#    {'ns': 10, 'exists': '', '*': 'Template:Namespace detect'},
#    {'ns': 10, 'exists': '', '*': 'Template:PAGENAMEBASE'},
#    {'ns': 10, 'exists': '', '*': 'Template:Category handler'},
#    {'ns': 10, 'exists': '', '*': 'Template:Disambiguation/cat'},
#    {'ns': 828, 'exists': '', '*': 'Module:Side box'},
#    {'ns': 828, 'exists': '', '*': 'Module:Yesno'},
#    {'ns': 828, 'exists': '', '*': 'Module:Side box/styles.css'},
#    {'ns': 828, 'exists': '', '*': 'Module:Check for unknown parameters'},
#    {'ns': 828, 'exists': '', '*': 'Module:String'},
#    {'ns': 828, 'exists': '', '*': 'Module:SDcat'},
#    {'ns': 828, 'exists': '', '*': 'Module:Namespace detect'},
#    {'ns': 828, 'exists': '', '*': 'Module:Namespace detect/data'},
#    {'ns': 828, 'exists': '', '*': 'Module:Namespace detect/config'},
#    {'ns': 828, 'exists': '', '*': 'Module:Arguments'},
#    {'ns': 828, 'exists': '', '*': 'Module:Category handler'},
#    {'ns': 828, 'exists': '', '*': 'Module:Category handler/data'},
#    {'ns': 828, 'exists': '', '*': 'Module:Category handler/config'},
#    {'ns': 828, 'exists': '', '*': 'Module:Category handler/shared'},
#    {'ns': 828, 'exists': '', '*': 'Module:Category handler/blacklist'},
#    {'ns': 828, 'exists': '', '*': 'Module:Redirect'}],
#   'images': ['Wiktionary-logo-en-v2.svg', 'Disambig_gray.svg'],
#   'externallinks': [],
#   'sections': [{'toclevel': 1,
#     'level': '2',
#     'line': 'Snakes',
#     'number': '1',
#     'index': '1',
#     'fromtitle': 'Python',
#     'byteoffset': 70,
#     'anchor': 'Snakes',
#     'linkAnchor': 'Snakes'},
#    {'toclevel': 1,
#     'level': '2',
#     'line': 'Computing',
#     'number': '2',
#     'index': '2',
#     'fromtitle': 'Python',
#     'byteoffset': 302,
#     'anchor': 'Computing',
#     'linkAnchor': 'Computing'},
#    {'toclevel': 1,
#     'level': '2',
#     'line': 'People',
#     'number': '3',
#     'index': '3',
#     'fromtitle': 'Python',
#     'byteoffset': 545,
#     'anchor': 'People',
#     'linkAnchor': 'People'},
#    {'toclevel': 1,
#     'level': '2',
#     'line': 'Roller coasters',
#     'number': '4',
#     'index': '4',
#     'fromtitle': 'Python',
#     'byteoffset': 874,
#     'anchor': 'Roller_coasters',
#     'linkAnchor': 'Roller_coasters'},
#    {'toclevel': 1,
#     'level': '2',
#     'line': 'Vehicles',
#     'number': '5',
#     'index': '5',
#     'fromtitle': 'Python',
#     'byteoffset': 1091,
#     'anchor': 'Vehicles',
#     'linkAnchor': 'Vehicles'},
#    {'toclevel': 1,
#     'level': '2',
#     'line': 'Weaponry',
#     'number': '6',
#     'index': '6',
#     'fromtitle': 'Python',
#     'byteoffset': 1223,
#     'anchor': 'Weaponry',
#     'linkAnchor': 'Weaponry'},
#    {'toclevel': 1,
#     'level': '2',
#     'line': 'Other uses',
#     'number': '7',
#     'index': '7',
#     'fromtitle': 'Python',
#     'byteoffset': 1423,
#     'anchor': 'Other_uses',
#     'linkAnchor': 'Other_uses'},
#    {'toclevel': 1,
#     'level': '2',
#     'line': 'See also',
#     'number': '8',
#     'index': '8',
#     'fromtitle': 'Python',
#     'byteoffset': 1785,
#     'anchor': 'See_also',
#     'linkAnchor': 'See_also'}],
#   'showtoc': '',
#   'parsewarnings': [],
#   'displaytitle': '<span class="mw-page-title-main">Python</span>',
#   'iwlinks': [{'prefix': 'wiktionary',
#     'url': 'https://en.wiktionary.org/wiki/Python',
#     '*': 'wiktionary:Python'},
#    {'prefix': 'wiktionary',
#     'url': 'https://en.wiktionary.org/wiki/python',
#     '*': 'wiktionary:python'}],
#   'properties': [{'name': 'wikibase-shortdesc',
#     '*': 'Topics referred to by the same term'},
#    {'name': 'toc', '*': ''},
#    {'name': 'disambiguation', '*': ''},
#    {'name': 'wikibase_item', '*': 'Q747452'}]}}

# %% [markdown]
# ### Exercise 2.2

# %% [markdown]
# You would like to know if Zürich or Bern is more popular on Wikipedia. For this purpose, you will measure (1) the number of Wikipedia articles within a 1km-radius around the train station and (2) the total number of images in these articles. Try to work with functions instead of copying and pasting code!
#
# You can take the following coordinates:
# * Bern: 46.949722, 7.439444
# * Zürich: 47.377455, 8.539688

# %% [markdown]
# Start by comparing the number of articles:

# %%
# Define function to get names of all articles

def getArts(coords):

  URL = "https://de.wikipedia.org/w/api.php"  # Change to German Wikipedia!
  PARAMS = {
      "format": "json",
      "list": "geosearch",
      "gscoord": coords,
      "gslimit": "max",
      "gsradius": 1000,
      "action": "query"
  }

  r = requests.get(url=URL, params=PARAMS)
  DATA = r.json()
  PLACES = DATA['query']['geosearch']
  results = [place["title"] for place in PLACES]
  return results

# %%
bern = getArts("46.949722|7.439444")
print(len(bern))
print(bern)
# Out:
# 206
# ['Bahnhof Bern', 'Hauptgebäude der Universität Bern', 'Golatenmatttor', 'Bollwerk (Bern)', 'Universität Bern', 'Hotel Schweizerhof (Bern)', 'Äusseres Aarbergertor', 'Grosse Schanze (Bern)', 'Rotes Quartier', 'Genfergasse (Bern)', 'Burgerspital', 'BLS AG', 'Schanzen (Bern)', 'Heiliggeistkirche (Bern)', 'Neuengasse', 'Aarbergergasse', 'Staatsarchiv des Kantons Bern', 'Ryffligässchen', 'Ryfflibrunnen', 'Schweizerische Theatersammlung', 'Stiftung SAPA, Schweizer Archiv der Darstellenden Künste', 'Speichergasse (Bern)', 'Christoffelturm', 'Bubenbergplatz', 'Haus der Kantone', 'Welle von Bern', 'Loebegge', 'Schweizer Reisekasse', 'Obergericht des Kantons Bern', 'Obere Altstadt', 'Spitalgasse (Bern)', 'Beratungsstelle für Unfallverhütung', 'Pfeiferbrunnen', 'Altes Schützenhaus (Bern)', 'Hodlerstrasse (Bern)', 'Kornhausplatz (Bern)', 'Christoffelgasse', 'Kunstmuseum Bern', 'Bernische Kunstgesellschaft', 'Bubenberg-Denkmal', 'Schwanengasse (Bern)', 'Progr', 'Sommerleist', 'Clientis', 'DC Bank', 'Theaterkubus (Bern)', 'Stiftung Science et Cité', 'Holländerturm', 'Waisenhausplatz (Bern)', 'Heilsarmee-Museum (Bern)', 'Kulturzentrum Reitschule', 'Meret-Oppenheim-Brunnen', 'Alpenegg', 'Käfigturm', 'Bärenplatz (Bern)', 'Bundesgasse', 'Bärenplatzbrunnen', 'Präsenz Schweiz', 'Hirschengraben (Bern)', 'Länggasse', 'Anna-Seiler-Brunnen', 'Bernerhof', 'Swissmedic', 'Blutturm (Bern)', 'Berner Kantonalbank', 'NMS Bern', 'Kantonalbankgebäude Bern', 'Weltpostdenkmal', 'Schweizerische Osteuropabibliothek', 'Eidgenössische Parlaments- und Zentralbibliothek', 'Bernabrunnen', 'Rote Brücke (Bern)', 'Valiant Bank', 'Bundesplatz (Bern)', 'Wasserspiel auf dem Bundesplatz', 'Von Graffenried Holding', 'Lorrainebrücke', 'Antikensammlung Bern', 'Lindenbrunnen (Bern)', 'Gesellschaft zu Ober-Gerwern', 'Robert Walser-Zentrum', 'Nägeligasse (Bern)', 'Zeughausgasse (Bern)', 'Burgerliche Ersparniskasse Bern', 'Die Landsgemeinde', 'Bundesratszimmer', 'Bundeshaus (Bern)', 'Predigergasse (Bern)', 'Rathaus zum Äusseren Stand', 'Lorraineviadukt', 'Gelbes Quartier', 'Die drei Eidgenossen', 'Dreifaltigkeitskirche (Bern)', 'Marktgasse (Bern)', 'Marzilibahn', 'Gesellschaft zu Schützen', 'Die Wiege der Eidgenossenschaft', 'Stadtbach (Berner Quartier)', 'Schüttestrasse (Bern)', 'Botanischer Garten Bern', 'Volkshaus Bern', 'Französische Kirche (Bern)', 'Bundesamt für Sozialversicherungen', 'Schützenbrunnen (Bern)', 'Donnerbühl/Stadtbach', 'Zunftgesellschaft zu Schmieden', 'Bank EEK', 'Kochergasse', 'Kornhaus (Bern)', 'Bundesamt für Justiz (Schweiz)', 'Gesellschaft zu Schuhmachern', 'Bundesamt für Zoll und Grenzsicherheit', 'Gesellschaftshaus zu Mittellöwen', 'Schweizerischer Anwaltsverband', 'Bühnen Bern', 'Kocherpark', 'Gesellschaft zu Mittellöwen', 'Innere Stadt (Bern)', 'Besetzung der rumänischen Botschaft in Bern', 'Kindlifresserbrunnen', 'Amthausgasse (Bern)', 'Synagoge (Bern)', 'Konferenz der Schweizer Denkmalpflegerinnen und Denkmalpfleger', 'Bern', 'Hotel Bellevue Palace', 'Theaterplatz (Bern)', 'Bundesamt für Berufsbildung und Technologie', 'Sport & Exercise Medicine Switzerland', 'Erlach-Denkmal', 'Hôtel de Musique', 'Volkshochschule Bern', 'Grabenpromenade (Bern)', 'Kornhausbrücke (Bern)', 'Gibb Berufsfachschule Bern', 'Altenbergsteg', 'Villette (Bern)', 'Monbijou (Bern)', 'Regionalgericht Bern-Mittelland', 'Schweizer Tourismus-Verband', 'Casinoplatz (Bern)', 'Burgerbibliothek Bern', 'Eidgenössische Alkoholverwaltung', 'Hohe Schule (Bern)', 'Casino Bern', 'Klinik Beau-Site', 'Bierhübeli', 'Dalmazibrücke', 'Berner Altstadt', 'Brückfeld (Bern)', 'Florapark Bern', 'Brunngasse', 'Zähringerbrunnen', 'Bibliothek Münstergasse', 'Krebsliga Schweiz', 'Krebsforschung Schweiz', 'Pauluskirche (Bern)', 'Kursaal Bern', 'Marzili (Berner Quartier)', 'Rathausgasse (Bern)', 'Grünes Quartier', 'Herrengassbrunnen', 'Herrengasse (Bern)', 'Brunngasshalde', 'Kirchenfeldbrücke', 'Einsteinhaus Bern', 'Zunftgesellschaft zu Metzgern', 'Grand Casino Bern', 'Kramgasse', 'Simsonbrunnen (Bern)', 'Vik ...

# %%
zurich = getArts("47.377455|8.539688")
len(zurich)
# Out:
# 223

# %% [markdown]
# Now try to compare the total number of images in these articles. You will have to write a loop to retrieve each page.

# %%
# Function to get number of images
def nrImg(pagename):
  URL = "https://de.wikipedia.org/w/api.php"

  PARAMS = {
      "action": "parse",
      "page": pagename,
      "format": "json",
  }

  r = requests.get(url=URL, params=PARAMS)
  DATA = r.json()
  nr_images = len(DATA["parse"]["images"])
  return nr_images

#print(nrImg("Burgerspital"))

# %%
# Compute total for Bern
bern_total = 0

for i in bern:
  images = nrImg(i)
  bern_total += images

print(bern_total) # total number of images
print(len(bern))
bern_total / len(bern) # average number of images per page
# Out:
# 1080
# 206
# 5.242718446601942

# %%
# Compute total for Zürich
zurich_total = 0

for i in zurich:
  images = nrImg(i)
  zurich_total += images

print(zurich_total) # total number of images
zurich_total / len(zurich) # average number of images per page
# Out:
# 1625
# 7.286995515695067
