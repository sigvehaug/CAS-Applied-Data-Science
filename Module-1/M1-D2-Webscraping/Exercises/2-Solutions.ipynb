# %% [markdown]
# ### Working with APIs##
# #Exercises#

# %% [markdown]
# ---
#
#
# <font color='violet'>
# Hints are written in white, so you do not see them immediately. If you highlight them (or double-click on them), they will appear!
# <font color='white'> I am a hint! :-)
#
#
# ---

# %% [markdown]
# ## 1. Basic exercises

# %% [markdown]
# Note: In these exercises, you will have to work with dictionaries, list comprehensions and loops quite often. If you don't remember/understand them very well, you should first go through the respective concepts once more!

# %% [markdown]
# ### Exercise 1.1

# %% [markdown]
# Import the ``requests`` and the ``BeautifulSoup`` library.

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# Use the Wikipedia API to retrieve the Wikipedia page on tigers (Tiger).

# %%
URL = "https://en.wikipedia.org/w/api.php"

PARAMS = {
    "action": "parse",
    "page": "Tiger",
    "format": "json",
}

r = requests.get(url=URL, params=PARAMS)

# %% [markdown]
# Parse the JSON response object (so that it is converted to a Python dictionary).

# %%
tiger = r.json()

# %% [markdown]
# What is the URL you retrieved the data from? Type it into your browser and inspect the structure of the data.

# %%
r.url
# Out:
# 'https://en.wikipedia.org/w/api.php?action=parse&page=Tiger&format=json'

# %% [markdown]
# Now inspect the keys of your dictionary (and those of the dictionary within the "parse" key)

# %%
tiger.keys()
# Out:
# dict_keys(['parse'])

# %%
tiger["parse"].keys()  
# Note: To save some coding below, you could type: tiger = tiger["parse"]
# Out:
# dict_keys(['title', 'pageid', 'revid', 'text', 'langlinks', 'categories', 'links', 'templates', 'images', 'externallinks', 'sections', 'showtoc', 'parsewarnings', 'displaytitle', 'iwlinks', 'properties'])

# %% [markdown]
# Now try to retrieve the following:
#
# 1. The title of the page
# 2. All external links
# 3. All section headings (*extra task: all main section headings, i.e. headings on level 2)
# 4. The number of images in the article
# 5. All URLs to Wikipedia articles on tigers in other languages

# %%
# 1. The title of the page
tiger["parse"]["title"]
# Out:
# 'Tiger'

# %%
# 2. All external links
print(tiger["parse"]["externallinks"])
# Out:
# ['https://www.iucnredlist.org/species/15955/214862019', 'https://doi.org/10.2305%2FIUCN.UK.2022-1.RLTS.T15955A214862019.en', 'https://archive.org/stream/mobot31753000798865#page/41/mode/2up', 'https://doi.org/10.1641%2FB570608', 'https://api.semanticscholar.org/CorpusID:85748043', 'https://www.biodiversitylibrary.org/page/8722619', 'https://www.perseus.tufts.edu/hopper/text?doc=Perseus:text:1999.04.0057:entry%3Dti/gris', 'http://www.etymonline.com/index.php?term=tiger', 'http://www.etymonline.com/index.php?term=panther', 'https://archive.org/details/journalofbomb33341929bomb/page/n133', 'https://archive.org/stream/PocockMammalia1/pocock1#page/n247/mode/2up', 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2624500', 'https://ui.adsabs.harvard.edu/abs/2009PLoSO...4.4125D', 'https://doi.org/10.1371%2Fjournal.pone.0004125', 'https://pubmed.ncbi.nlm.nih.gov/19142238', 'http://www.departments.bucknell.edu/biology/resources/msw3/browse.asp?id=14000259', 'http://www.google.com/books?id=JgAMbNSt8ikC&pg=PA546', 'https://www.worldcat.org/oclc/62265494', 'https://books.google.com/books?id=dbQ8AAAAIAAJ&pg=PA19', 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC
'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3189913', 'https://ui.adsabs.harvard.edu/abs/2011PLoSO...625483M', 'https://doi.org/10.1371%2Fjournal.pone.0025483', 'https://pubmed.ncbi.nlm.nih.gov/22016768', 'https://books.google.com/books?id=66mRJSxIAfoC', 'https://books.google.com/books?id=XFIbjBEQolMC&pg=PA53', 'https://www ...

# %%
# 3. All section headings 
sections = tiger["parse"]["sections"]
[section["line"] for section in sections]

# %%
# 3. Extra task: all top level section headings (level 2)
[section["line"] for section in sections if section["level"]=="2"]

# %%
# 4. The number of images in the article
len(tiger["parse"]["images"])
# Out:
# 66

# %%
# 5. All URLs to Wikipedia articles on tigers in other languages
languages = tiger["parse"]["langlinks"]

langlinks = [elem["url"] for elem in languages]
print(langlinks)
# Out:
# ['https://ace.wikipedia.org/wiki/Rimu%C3%ABng', 'https://kbd.wikipedia.org/wiki/%D0%A5%D1%8C%D1%8D%D1%89%D0%BE%D0%BC%D1%8B%D1%89', 'https://ady.wikipedia.org/wiki/%D0%9A%D1%8A%D1%8D%D0%BF%D0%BB%D1%8A%D0%B0%D0%BD', 'https://af.wikipedia.org/wiki/Tier', 'https://als.wikipedia.org/wiki/Tiger', 'https://am.wikipedia.org/wiki/%E1%8A%90%E1%89%A5%E1%88%AD', 'https://ang.wikipedia.org/wiki/Tiger', 'https://ar.wikipedia.org/wiki/%D8%A8%D8%A8%D8%B1', 'https://an.wikipedia.org/wiki/Panthera_tigris', 'https://roa-rup.wikipedia.org/wiki/Tigru', 'https://ast.wikipedia.org/wiki/Panthera_tigris', 'https://gn.wikipedia.org/wiki/Jaguareterusu', 'https://az.wikipedia.org/wiki/P%C9%99l%C9%99ng', 'https://azb.wikipedia.org/wiki/%D9%82%D8%A7%D9%BE%D9%84%D8%A7%D9%86', 'https://ban.wikipedia.org/wiki/Macan', 'https://bn.wikipedia.org/wiki/%E0%A6%AC%E0%A6%BE%E0%A6%98', 'https://zh-min-nan.wikipedia.org/wiki/H%C3%B3%CD%98', 'https://ba.wikipedia.org/wiki/%D0%AE%D0%BB%D0%B1%D0%B0%D1%80%D1%8B%D2%AB', 'https://be.wikipedia.org/wiki/%D0%A2%D1%8B%D0%B3%D1%80', 'https://be-tarask.wikipedia.org/wiki/%D0%A2%D1%8B%D0%B3%D1%80', 'https://bh.wikipedia.org/wiki/%E0%A4%AC%E0%A4%BE%E0%A4%98', 'https://bcl.wikipedia.org/wiki/Tigre', 'https://bg.wikipedia.org/wiki/%D0%A2%D0%B8%D0%B3%D1%8A%D1%80', 'https://bo.wikipedia.org/wiki/%E0%BD%A6%E0%BE%9F%E0%BD%82', 'https://bs.wikipedia.org/wiki/Tigar', 'https://br.wikipedia.org/wiki/Tigr', 'https://bxr.wikipedia.org/wiki/%D0%91%D0%B0%D1%80', 'https://ca.wikipedia.org/wiki/Tigre', 'https://cv.wikipedia.org/wiki/%D0%A2%D0%B8%D0%B3%D1%80', 'https://ceb.wikipedia.org/wiki/Panthera_tigris', 'https://cs.wikipedia.org/wiki/Tygr', 'https://co.wikipedia.org/wiki/Tigru', 'https://c
# %% [markdown]
# Repetition (dictionaries and loops): Now make a dictionary of all languages for which a Wikipedia page exists as well as the titles of these pages. Use the languages as keys and the titles as values (`{"English":"Tiger", ...}`). How are tigers called in `Finnish`?

# %%
tiger_lang = {"English":"Tiger"}
for elem in languages:
  tiger_lang[elem["langname"]] = elem["*"]
tiger_lang

# %%
tiger_lang["Finnish"]

# %% [markdown]
# ### Exercise 1.2

# %% [markdown]
# Find the HTML text within the structured data on the tiger page and assign it to a variable named ``htmlText``.

# %%
htmlText = tiger["parse"]["text"]["*"]

# %% [markdown]
# Convert the string to a BeautifulSoup object and assign it to a variable called ``tigerSoup``.

# %%
tigerSoup = BeautifulSoup(htmlText)

# %% [markdown]
# Repetitition: Extract (1) the first table and (2) the third paragraph of the article.

# %%
tigerSoup.find("table")

# %%
tigerSoup.find_all("p")[2]

# %% [markdown]
# ### Exercise 1.3

# %% [markdown]
# Retrieve the information about 10 Wikipedia pages that match with the word "tiger" and convert the response to a dictionary. ><font color='violet'> Hint: <font color='white'> Hint: The "srlimit" parameter allows you to specify how many pages you want to retrieve.

# %%
# Perform page search 
URL = "https://en.wikipedia.org/w/api.php"

PARAMS = {
    "action": "query",
    "format": "json",
    "list": "search",
    "srsearch": "tiger",
    "srlimit": 10
}

r = requests.get(url=URL, params=PARAMS)

# Convert to dictionary
tigers = r.json()

# %% [markdown]
# Navigate through the dictionary or type the URL into your browser to inspect how the data is structured.

# %%
# Get URL so you can explore the structure of the data in your Browser
r.url
# Out:
# 'https://en.wikipedia.org/w/api.php?action=query&format=json&list=search&srsearch=tiger&srlimit=10'

# %%
# Explore the dictionary
print(tigers.keys())
print(tigers["query"].keys())
type(tigers["query"]["search"]) # tigers["query"]["search"] contains a list of dictionaries!
# Out:
# dict_keys(['batchcomplete', 'continue', 'query'])
# dict_keys(['searchinfo', 'search'])
# list

# %% [markdown]
# Now print out the titles of the 10 tiger pages.

# %%
# Extract titles
tiger_pages = tigers["query"]["search"]

[elem["title"] for elem in tiger_pages]
# Out:
# ['Tiger',
#  'Topologically Integrated Geographic Encoding and Referencing',
#  'Tiger Tiger',
#  'Tiger Woods',
#  'Tiger Shroff',
#  'Bengal tiger',
#  'Tiger shark',
#  'Tiger (zodiac)',
#  'Siberian tiger',
#  'Tiger II']

# %% [markdown]
# ### Exercise 1.4

# %% [markdown]
# In the web scraping exercises, you wrote a simple scraper that fetched you some information from the following animal pages:

# %%
animals = ["Cat", "Dog", "Tiger", "Giant_panda"]

# %% [markdown]
# You will now try to do the same using the API: Write a loop that fetches all the pages and retrieves (1) the title and (2) the number of images on each page.

# %% [markdown]
# Let's do this step by step. First try to fetch the "Cat" page and convert the JSON response you get into a Python dictionary.

# %%
URL = "https://en.wikipedia.org/w/api.php"

PARAMS = {
    "action": "parse",
    "page": "Cat",
    "format": "json",
}

r = requests.get(url=URL, params=PARAMS)
data = r.json()

# %% [markdown]
# Now try to retrieve the title and the number of images. Assign each of them to a variable.

# %%
title = data["parse"]["title"]
images = len(data["parse"]["images"])
print(title, images)
# Out:
# Cat 49

# %% [markdown]
# Now write a loop that fetches all the pages and writes the response into a list. You will have to create an empty list and ``append`` the new elements to it:

# %%
L = []
for pagename in animals:
  URL = "https://en.wikipedia.org/w/api.php"

  PARAMS = {
        "action": "parse",
        "page": pagename,
        "format": "json",
        }

  r = requests.get(url=URL, params=PARAMS)
  L.append(r)

L
# Out:
# [<Response [200]>, <Response [200]>, <Response [200]>, <Response [200]>]

# %% [markdown]
# Finally, you can bring everything together. Improve your loop so that it parses each page, retrieves the title and the number of images and writes them into a nested list.

# %%
L = []
for pagename in animals:
  URL = "https://en.wikipedia.org/w/api.php"

  PARAMS = {
        "action": "parse",
        "page": pagename,
        "format": "json",
        }

  r = requests.get(url=URL, params=PARAMS)
  data = r.json()

  title = data["parse"]["title"]
  images = len(data["parse"]["images"])

  L.append([title, images])

L
# Out:
# [['Cat', 49], ['Dog', 38], ['Tiger', 66], ['Giant panda', 31]]

# %% [markdown]
# ## 2. Advanced exercises*

# %% [markdown]
# ---
#
#
# <font color='red'>
# *Feel free to skip the advanced exercises if you feel overwhelmed or if trying to solve the basic exercises already took you a lot of time!
#
#
# ---

# %% [markdown]
# ### Exercise 2.1

# %% [markdown]
# Write a function called ``getWiki`` that allows you to enter the name of a Wikipedia page and returns the parsed JSON response as a Python dictionary.

# %%
def getWiki(pagename):
  ENDPOINT = "https://en.wikipedia.org/w/api.php"

  PARAMS = {
      "action": "parse",
      "page": pagename,
      "format": "json",
  }

  r = requests.get(url=ENDPOINT, params=PARAMS)
  return r.json()

# %%
getWiki("Python")

# %% [markdown]
# ### Exercise 2.2

# %% [markdown]
# You would like to know if Zürich or Bern is more popular on Wikipedia. For this purpose, you will measure (1) the number of Wikipedia articles within a 1km-radius around the train station and (2) the total number of images in these articles. Try to work with functions instead of copying and pasting code!
#
# You can take the following coordinates:
# * Bern: 46.949722, 7.439444
# * Zürich: 47.377455, 8.539688

# %% [markdown]
# Start by comparing the number of articles:

# %%
# Define function to get names of all articles

def getArts(coords):

  URL = "https://de.wikipedia.org/w/api.php"  # Change to German Wikipedia!
  PARAMS = {
      "format": "json",
      "list": "geosearch",
      "gscoord": coords,
      "gslimit": "max",
      "gsradius": 1000, 
      "action": "query"
  }

  r = requests.get(url=URL, params=PARAMS)
  DATA = r.json()
  PLACES = DATA['query']['geosearch']
  results = [place["title"] for place in PLACES]
  return results

# %%
bern = getArts("46.949722|7.439444")
print(len(bern))
print(bern)
# Out:
# 197
# ['Bahnhof Bern', 'Hauptgebäude der Universität Bern', 'Golatenmatttor', 'Bollwerk (Bern)', 'Universität Bern', 'Hotel Schweizerhof (Bern)', 'Äusseres Aarbergertor', 'Grosse Schanze (Bern)', 'Rotes Quartier', 'Genfergasse (Bern)', 'Burgerspital', 'BLS AG', 'Schanzen (Bern)', 'Heiliggeistkirche (Bern)', 'Neuengasse', 'Aarbergergasse', 'Staatsarchiv des Kantons Bern', 'Ryffligässchen', 'Ryfflibrunnen', 'Schweizerische Theatersammlung', 'Stiftung SAPA, Schweizer Archiv der Darstellenden Künste', 'Speichergasse (Bern)', 'Christoffelturm', 'Bubenbergplatz', 'Haus der Kantone', 'Welle von Bern', 'Loebegge', 'Schweizer Reisekasse', 'Obergericht des Kantons Bern', 'Obere Altstadt', 'Spitalgasse (Bern)', 'Pfeiferbrunnen', 'Altes Schützenhaus (Bern)', 'Hodlerstrasse (Bern)', 'Christoffelgasse', 'Kunstmuseum Bern', 'Bernische Kunstgesellschaft', 'Bubenberg-Denkmal', 'Schwanengasse (Bern)', 'Progr', 'Sommerleist', 'Clientis', 'DC Bank', 'Holländerturm', 'Waisenhausplatz (Bern)', 'Heilsarmee-Museum (Bern)', 'Kulturzentrum Reitschule', 'Meret-Oppenheim-Brunnen', 'Alpenegg', 'Käfigturm', 'Bärenplatz (Bern)', 'Bundesgasse', 'Bärenplatzbrunnen', 'Präsenz Schweiz', 'Hirschengraben (Bern)', 'Anna-Seiler-Brunnen', 'Bernerhof', 'Swissmedic', 'Blutturm (Bern)', 'Berner Kantonalbank', 'NMS Bern', 'Kantonalbankgebäude Bern', 'Weltpostdenkmal', 'Schweizerische Osteuropabibliothek', 'Eidgenössische Parlaments- und Zentralbibliothek', 'Bernabrunnen', 'Rote Brücke (Bern)', 'Valiant Bank', 'Bundesplatz (Bern)', 'Von Graffenried Holding', 'Lorrainebrücke', 'Antikensammlung Bern', 'Lindenbrunnen (Bern)', 'Gesellschaft zu Ober-Gerwern', 'Robert Walser-Zentrum', 'Nägeligasse (Bern)', 'Burgerliche Ersparniskasse Bern', 'Die Landsgemeinde', 'Bundeshaus (Bern)', 'Predigergasse (Bern)', 'Rathaus zum Äusseren Stand', 'Lorraineviadukt', 'Gelbes Quartier', 'Die drei Eidgenossen', 'Dreifaltigkeitskirche (Bern)', 'Marktgasse (Bern)', 'Marzilibahn', 'Gesellschaft zu Schützen', 'Die Wiege der Eidgenossenschaft', 'Stadtbach (Berner Quartier)', 'Schüttestrasse (Bern)', 'Botanischer Garten Bern', 'Volkshaus Bern', 'Französische Kirche (Bern)', 'Bundesamt für Sozialversicherungen', 'Schützenbrunnen (Bern)', 'Donnerbühl/Stadtbach', 'Zunftgesellschaft zu Schmieden', 'Bank EEK', 'Kochergasse', 'Schweizerischer Innovationspark', 'Kornhaus (Bern)', 'Bundesamt für Justiz (Schweiz)', 'Gesellschaft zu Schuhmachern', 'Bundesamt für Zoll und Grenzsicherheit', 'Gesellschaftshaus zu Mittellöwen', 'Schweizerischer Anwaltsverband', 'Bühnen Bern', 'Kocherpark', 'Gesellschaft zu Mittellöwen', 'Innere Stadt (Bern)', 'Besetzung der rumänischen Botschaft in Bern', 'Kindlifresserbrunnen', 'Amthausgasse (Bern)', 'Synagoge (Bern)', 'Konferenz der Schweizer Denkmalpflegerinnen und Denkmalpfleger', 'Bern', 'Hotel Bellevue Palace', 'Theaterplatz (Bern)', 'Bundesamt für Berufsbildung und Technologie', 'Sport & Exercise Medicine Switzerland', 'Zytglogge', 'Erlach-Denkmal', 'Hôtel de Musique', 'Volkshochschule Bern', 'Grabenpromenade (Bern)', 'Kornhausbrücke (Bern)', 'Gibb Berufsfachschule Bern', 'Altenbergsteg', 'Villette (Bern)', 'Regionalgericht Bern-Mittelland', 'Schweizer Tourismus-Verband', 'Casinoplatz (Bern)', 'Burgerbibliothek Bern', 'Eidgenössische Alkoholverwaltung', 'Casino Bern', 'Hohe Schule (Bern)', 'Klinik Beau-Site', 'Bierhübeli', 'Dalmazibrücke', 'Berner Altstadt', 'Brückfeld (Bern)', 'Florapark Bern', 'Brunngasse', 'Zähringerbrunnen', 'Bibliothek Münstergasse', 'Krebsliga Schweiz', 'Krebsforschung Schweiz', 'Pauluskirche (Bern)', 'Kursaal Bern', 'Marzili (Berner Quartier)', 'Grünes Quartier', 'Herrengassbrunnen', 'Herrengasse (Bern)', 'Brunngasshalde', 'Kirchenfeldbrücke', 'Einsteinhaus Bern', 'Zunftgesellschaft zu Metzgern', 'Grand Casino Bern', 'Kramgasse', 'Simsonbrunnen (Bern)', 'Viktoriaspital (Bern)', 'Berner Fachhochschule, Departement Wirtschaft', 'Ukrainische Botschaft in Bern', 'Stettbrunnen', 'Tscharnerhaus (Herrengasse 4)', 'Mosesbrunnen (Bern)', 'Gesellschaft zu Kaufleut ...

# %%
zurich = getArts("47.377455|8.539688")
len(zurich)
# Out:
# 213

# %% [markdown]
# Now try to compare the total number of images in these articles. You will have to write a loop to retrieve each page.

# %%
# Function to get number of images
def nrImg(pagename):
  URL = "https://de.wikipedia.org/w/api.php"

  PARAMS = {
      "action": "parse",
      "page": pagename,
      "format": "json",
  }

  r = requests.get(url=URL, params=PARAMS)
  DATA = r.json()
  nr_images = len(DATA["parse"]["images"])
  return nr_images

#print(nrImg("Burgerspital"))
# Out:
# 8

# %%
# Compute total for Bern
bern_total = 0

for i in bern:
  images = nrImg(i)
  bern_total += images

print(bern_total) # total number of images
print(len(bern))
bern_total / len(bern) # average number of images per page
# Out:
# 921
# 197
# 4.675126903553299

# %%
# Compute total for Zürich
zurich_total = 0

for i in zurich:
  images = nrImg(i)
  zurich_total += images

print(zurich_total) # total number of images
zurich_total / len(zurich) # average number of images per page
# Out:
# 1609
# 7.553990610328638
