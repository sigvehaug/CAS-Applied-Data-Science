# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6c9c78cf-22a9-41a9-abb9-7d6c75c753ea" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6c9c78cf-22a9-41a9-abb9-7d6c75c753ea">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
dataframe = pd.read_csv('iris.csv', dtype='str', header=0, names=['slength', 'swidth', 'plength', 'pwidth', 'spieces'])

# %%
dataframe
# Out:
#     slength swidth plength pwidth         spieces
# 0       4.9    3.0     1.4    0.2     Iris-setosa
# 1       4.7    3.2     1.3    0.2     Iris-setosa
# 2       4.6    3.1     1.5    0.2     Iris-setosa
# 3       5.0    3.6     1.4    0.2     Iris-setosa
# 4       5.4    3.9     1.7    0.4     Iris-setosa
# ..      ...    ...     ...    ...             ...
# 144     6.7    3.0     5.2    2.3  Iris-virginica
# 145     6.3    2.5     5.0    1.9  Iris-virginica
# 146     6.5    3.0     5.2    2.0  Iris-virginica
# 147     6.2    3.4     5.4    2.3  Iris-virginica
# 148     5.9    3.0     5.1    1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
pd.set_option('display.max_rows', 10)

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   slength  149 non-null    object
#  1   swidth   149 non-null    object
#  2   plength  149 non-null    object
#  3   pwidth   149 non-null    object
#  4   spieces  149 non-null    object
# dtypes: object(5)
# memory usage: 5.9+ KB

# %%
dataframe_slice = dataframe[0:20]

# %%
dataframe_slice
# Out:
#    slength swidth plength pwidth      spieces
# 0      4.9    3.0     1.4    0.2  Iris-setosa
# 1      4.7    3.2     1.3    0.2  Iris-setosa
# 2      4.6    3.1     1.5    0.2  Iris-setosa
# 3      5.0    3.6     1.4    0.2  Iris-setosa
# 4      5.4    3.9     1.7    0.4  Iris-setosa
# ..     ...    ...     ...    ...          ...
# 15     5.4    3.9     1.3    0.4  Iris-setosa
# 16     5.1    3.5     1.4    0.3  Iris-setosa
# 17     5.7    3.8     1.7    0.3  Iris-setosa
# 18     5.1    3.8     1.5    0.3  Iris-setosa
# 19     5.4    3.4     1.7    0.2  Iris-setosa
#
# [20 rows x 5 columns]

# %%
dataframe.describe()
# Out:
#        slength swidth plength pwidth          spieces
# count      149    149     149    149              149
# unique      35     23      43     22                3
# top        5.0    3.0     1.5    0.2  Iris-versicolor
# freq        10     26      14     27               50

# %%
# Write your code here
url = 'https://www.covid19.admin.ch/api/data/20210823-4c27ic5b/sources/COVID19VaccPersons_v2.json'
# url = 'https://www.covid19.admin.ch/api/data/20230815-7ixiby4u/sources/COVID19Death_geoRegion_sex_w.csv'
df = pd.read_csv(url)
df

# %%
dataframe.iat[0,-1] = 'Iris-setosa'

# %% [markdown]
# # loc or iloc

# %%
dataframe
# Out:
#     slength swidth plength pwidth         spieces
# 0       4.9    3.0     1.4    0.2     Iris-setosa
# 1       4.7    3.2     1.3    0.2     Iris-setosa
# 2       4.6    3.1     1.5    0.2     Iris-setosa
# 3       5.0    3.6     1.4    0.2     Iris-setosa
# 4       5.4    3.9     1.7    0.4     Iris-setosa
# ..      ...    ...     ...    ...             ...
# 144     6.7    3.0     5.2    2.3  Iris-virginica
# 145     6.3    2.5     5.0    1.9  Iris-virginica
# 146     6.5    3.0     5.2    2.0  Iris-virginica
# 147     6.2    3.4     5.4    2.3  Iris-virginica
# 148     5.9    3.0     5.1    1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
dataframe.loc[4:10,'plength']
# Out:
# 4     1.7
# 5     1.4
# 6     1.5
# 7     1.4
# 8     1.5
# 9     1.5
# 10    1.6
# Name: plength, dtype: object

# %%
dataframe.iloc[4:10,1:3]
# Out:
#   swidth plength
# 4    3.9     1.7
# 5    3.4     1.4
# 6    3.4     1.5
# 7    2.9     1.4
# 8    3.1     1.5
# 9    3.7     1.5

# %%
dataframe['spieces']
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 144    Iris-virginica
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# Name: spieces, Length: 149, dtype: object

# %%
dataframe[0:3]
# Out:
#   slength swidth plength pwidth      spieces
# 0     4.9    3.0     1.4    0.2  Iris-setosa
# 1     4.7    3.2     1.3    0.2  Iris-setosa
# 2     4.6    3.1     1.5    0.2  Iris-setosa

# %%
dataframe['spieces'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
dataframe[dataframe['spieces']=='Iris-setosa']
# Out:
#    slength swidth plength pwidth      spieces
# 0      4.9    3.0     1.4    0.2  Iris-setosa
# 1      4.7    3.2     1.3    0.2  Iris-setosa
# 2      4.6    3.1     1.5    0.2  Iris-setosa
# 3      5.0    3.6     1.4    0.2  Iris-setosa
# 4      5.4    3.9     1.7    0.4  Iris-setosa
# ..     ...    ...     ...    ...          ...
# 44     4.8    3.0     1.4    0.3  Iris-setosa
# 45     5.1    3.8     1.6    0.2  Iris-setosa
# 46     4.6    3.2     1.4    0.2  Iris-setosa
# 47     5.3    3.7     1.5    0.2  Iris-setosa
# 48     5.0    3.3     1.4    0.2  Iris-setosa
#
# [49 rows x 5 columns]

# %% [markdown]
# vector operations

# %%
dataframe.iloc[:,0:4] = dataframe.iloc[:,0:4].astype(float)

# %%
dataframe['half slenght'] = dataframe['slength']/2.

# %%
grouped_by_spiecie = dataframe.groupby('spieces')

# %%
grouped_by_spiecie.size
# Out:
# <bound method GroupBy.size of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7d7236a42750>>

# %%
dataframe.sort_values(['slength', 'swidth'], ascending=[False, True])
# Out:
#      slength swidth plength pwidth         spieces  half slenght
# 130      7.9    3.8     6.4    2.0  Iris-virginica          3.95
# 117      7.7    2.6     6.9    2.3  Iris-virginica          3.85
# 121      7.7    2.8     6.7    2.0  Iris-virginica          3.85
# 134      7.7    3.0     6.1    2.3  Iris-virginica          3.85
# 116      7.7    3.8     6.7    2.2  Iris-virginica          3.85
# ..       ...    ...     ...    ...             ...           ...
# 40       4.5    2.3     1.3    0.3     Iris-setosa          2.25
# 7        4.4    2.9     1.4    0.2     Iris-setosa          2.20
# 37       4.4    3.0     1.3    0.2     Iris-setosa          2.20
# 41       4.4    3.2     1.3    0.2     Iris-setosa          2.20
# 12       4.3    3.0     1.1    0.1     Iris-setosa          2.15
#
# [149 rows x 6 columns]

# %%
dataframe[(dataframe['slength']>=5.)]
# Out:
#      slength swidth plength pwidth         spieces  half slenght
# 3        5.0    3.6     1.4    0.2     Iris-setosa          2.50
# 4        5.4    3.9     1.7    0.4     Iris-setosa          2.70
# 6        5.0    3.4     1.5    0.2     Iris-setosa          2.50
# 9        5.4    3.7     1.5    0.2     Iris-setosa          2.70
# 13       5.8    4.0     1.2    0.2     Iris-setosa          2.90
# ..       ...    ...     ...    ...             ...           ...
# 144      6.7    3.0     5.2    2.3  Iris-virginica          3.35
# 145      6.3    2.5     5.0    1.9  Iris-virginica          3.15
# 146      6.5    3.0     5.2    2.0  Iris-virginica          3.25
# 147      6.2    3.4     5.4    2.3  Iris-virginica          3.10
# 148      5.9    3.0     5.1    1.8  Iris-virginica          2.95
#
# [127 rows x 6 columns]

# %%
dataframe[(dataframe['slength']>=5.)].to_csv('/content/drive/MyDrive/myout.csv')
